# %% [markdown]
# # 06 — Cross-Dataset Benchmark: OOD Probe Evaluation
#
# **Goal:** Evaluate TriviaQA-trained probes on out-of-distribution datasets to measure generalization.
#
# - Probes are **frozen** (trained in notebook 05 on TriviaQA) — no retraining here.
# - We run the full semantic energy pipeline on a new dataset and compare:
#   - **Teachers** (full 5-sample generation + clustering) as upper bound
#   - **SLT / TBG probes** (single forward pass) as efficient alternatives
# - All metrics are computed against **ground-truth correctness**, not teacher labels.
#
# Run this notebook **three times** with different `EVAL_DATASET` settings:
# 1. `trivia_qa` (held-out, offset=1000) — in-distribution baseline
# 2. `nq_open` — Natural Questions Open
# 3. `squad` — Stanford Question Answering Dataset

# %% [markdown]
# ## 0 — Configuration

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION — Change EVAL_DATASET to switch benchmark target
# ══════════════════════════════════════════════════════════════════════════════

MODEL_ID            = "Qwen/Qwen3-8B"
USE_8BIT            = True

# ── Evaluation dataset (change this per run) ─────────────────────────────────
EVAL_DATASET        = "nq_open"      # "trivia_qa", "nq_open", or "squad"
EVAL_DATASET_CONFIG = None            # "rc" for trivia_qa, None for others
EVAL_SPLIT          = "validation"
DATASET_OFFSET      = 0              # For trivia_qa: set to 1000 to skip training data

# ── Training dataset (probes were trained on this) ───────────────────────────
TRAIN_DATASET       = "trivia_qa"

# ── Generation settings ──────────────────────────────────────────────────────
NUM_QUESTIONS       = 200
NUM_SAMPLES         = 5
CHECKPOINT_EVERY    = 50

# ── Derived names (auto-generated) ───────────────────────────────────────────
import re
MODEL_SHORT  = re.sub(r'[^a-z0-9]', '-', MODEL_ID.split('/')[-1].lower()).strip('-')
EVAL_SHORT   = EVAL_DATASET.replace('_', '')
TRAIN_SHORT  = TRAIN_DATASET.replace('_', '')
MODEL_LABEL  = MODEL_ID.split('/')[-1]

# Probe bundle comes from training dataset
PROBE_FILENAME = f"probes_{MODEL_SHORT}_{TRAIN_SHORT}.pkl"

print(f"Model:          {MODEL_ID}")
print(f"Eval dataset:   {EVAL_DATASET} (offset={DATASET_OFFSET})")
print(f"Train dataset:  {TRAIN_DATASET} (probes from)")
print(f"Questions:      {NUM_QUESTIONS} x {NUM_SAMPLES} samples")
print(f"Probe bundle:   {PROBE_FILENAME}")
# Out:
# Model:          Qwen/Qwen3-8B
# Eval dataset:   nq_open (offset=0)
# Train dataset:  trivia_qa (probes from)
# Questions:      200 x 5 samples
# Probe bundle:   probes_qwen3-8b_triviaqa.pkl

# %%
import sys, os, re, math, pickle, glob, time, warnings, hashlib
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from scipy.stats import spearmanr
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (roc_auc_score, average_precision_score,
                             roc_curve, precision_recall_curve,
                             confusion_matrix, ConfusionMatrixDisplay)
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings('ignore')

REPO_ROOT    = os.path.abspath(os.path.join(os.getcwd(), '..'))
BACKEND_PATH = os.path.join(REPO_ROOT, 'backend')
DATA_DIR     = os.path.join(REPO_ROOT, 'backend', 'data')
MODELS_DIR   = os.path.join(REPO_ROOT, 'backend', 'models')
FIGS_DIR     = os.path.join(REPO_ROOT, 'notebooks', 'figures')
for d in [DATA_DIR, MODELS_DIR, FIGS_DIR]:
    os.makedirs(d, exist_ok=True)
if BACKEND_PATH not in sys.path:
    sys.path.insert(0, BACKEND_PATH)

np.random.seed(42)
print(f"Repo root : {REPO_ROOT}")
print(f"Data dir  : {DATA_DIR}")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
# Out:
# Repo root : d:\Github Repositories\SemanticEnergy
# Data dir  : d:\Github Repositories\SemanticEnergy\backend\data
# CUDA: True
# GPU: NVIDIA GeForce RTX 3060
# VRAM: 12.0 GB

# %%
# ── Load pre-trained probe bundle ────────────────────────────────────────────
PROBE_PATH = os.path.join(MODELS_DIR, PROBE_FILENAME)
assert os.path.exists(PROBE_PATH), f"Probe bundle not found: {PROBE_PATH}\nRun notebook 05 first."

with open(PROBE_PATH, 'rb') as f:
    probe_bundle = pickle.load(f)

# Reconstruct trained_probes dict (same format notebook 05 uses)
trained_probes = {}
for prefix in ['slt_energy', 'tbg_energy', 'slt_entropy', 'tbg_entropy']:
    tok = 'slt' if prefix.startswith('slt') else 'tbg'
    teacher = 'energy' if 'energy' in prefix else 'entropy'
    lr_key = f'best_{teacher}_{tok}_range'
    trained_probes[prefix] = {
        'probe':       probe_bundle[f'{prefix}_probe'],
        'scaler':      probe_bundle[f'{prefix}_scaler'],
        'layer_range': probe_bundle[lr_key],
        'token':       tok,
    }

T_energy  = probe_bundle['energy_threshold']
T_entropy = probe_bundle['entropy_threshold']

print(f"Probe bundle loaded: {PROBE_FILENAME}")
print(f"  Trained on:       {probe_bundle.get('model_id', 'N/A')} / {probe_bundle.get('dataset', 'N/A')}")
print(f"  T_energy={T_energy:.4f}, T_entropy={T_entropy:.4f}")
for p, info in trained_probes.items():
    print(f"  {p}: layers {info['layer_range']}, token={info['token']}")
# Out:
# Probe bundle loaded: probes_qwen3-8b_triviaqa.pkl
#   Trained on:       Qwen/Qwen3-8B / trivia_qa
#   T_energy=0.6682, T_entropy=0.5556
#   slt_energy: layers (24, 28), token=slt
#   tbg_energy: layers (7, 11), token=tbg
#   slt_entropy: layers (24, 28), token=slt
#   tbg_entropy: layers (7, 11), token=tbg

# %% [markdown]
# ## 1 — Dataset Loading & Generation

# %%
# ── Dataset adapter: universal get_refs / get_uid / correctness ───────────────

def normalize_answer(text):
    text = text.lower()
    text = re.sub(r'\b(a|an|the)\b', ' ', text)
    text = re.sub(r'[^\w\s]', '', text)
    return ' '.join(text.split())

def is_correct(predicted_answer, reference_aliases):
    """Normalized substring match — works for TriviaQA, NQ-Open, SQuAD."""
    norm_pred = normalize_answer(predicted_answer)
    for ref in reference_aliases:
        if normalize_answer(ref) in norm_pred:
            return 1.0
    return 0.0

def get_refs(example):
    """Extract reference answers as a flat list of strings, any dataset format."""
    # TriviaQA: example['answer'] is a dict with 'aliases' key
    if 'answer' in example and isinstance(example['answer'], dict):
        return example['answer'].get('aliases', [example['answer'].get('value', '')])
    # NQ-Open: example['answer'] is a list of strings
    if 'answer' in example and isinstance(example['answer'], list):
        return example['answer']
    # SQuAD: example['answers'] (plural) has 'text' key (list of strings)
    if 'answers' in example:
        ans = example['answers']
        if isinstance(ans, dict) and 'text' in ans:
            return ans['text']
        if isinstance(ans, list):
            return [a['text'] if isinstance(a, dict) else str(a) for a in ans]
    return []

def get_uid(example):
    """Extract a unique ID from any dataset format."""
    for key in ['question_id', 'id', 'uid']:
        if key in example:
            return str(example[key])
    return hashlib.md5(example['question'].encode()).hexdigest()

correctness_fn = is_correct

# Quick sanity check
assert is_correct("The capital of France is Paris.", ["Paris"]) == 1.0
assert is_correct("Rolling Stones", ["The Beatles"]) == 0.0
print("Dataset adapter functions defined.")
# Out:
# Dataset adapter functions defined.

# %%
# ── Load evaluation dataset ──────────────────────────────────────────────────
from datasets import load_dataset

if EVAL_DATASET_CONFIG:
    raw_dataset = load_dataset(EVAL_DATASET, EVAL_DATASET_CONFIG, split=EVAL_SPLIT)
else:
    raw_dataset = load_dataset(EVAL_DATASET, split=EVAL_SPLIT)

end_idx = min(DATASET_OFFSET + NUM_QUESTIONS, len(raw_dataset))
dataset_subset = raw_dataset.select(range(DATASET_OFFSET, end_idx))
actual_n = len(dataset_subset)

print(f"Dataset:   {EVAL_DATASET} ({EVAL_SPLIT})")
print(f"Total:     {len(raw_dataset)} examples")
print(f"Selected:  [{DATASET_OFFSET}:{end_idx}] = {actual_n} examples")

# Validate adapter on first example
ex = dataset_subset[0]
refs = get_refs(ex)
uid  = get_uid(ex)
print(f"\nFirst example:")
print(f"  Q:    {ex['question'][:100]}")
print(f"  Refs: {refs[:5]}")
print(f"  UID:  {uid}")
assert len(refs) > 0, "get_refs() returned empty — check adapter logic for this dataset"
# Out:
# Dataset:   nq_open (validation)
# Total:     3610 examples
# Selected:  [0:200] = 200 examples
#
# First example:
#   Q:    when was the last time anyone was on the moon
#   Refs: ['14 December 1972 UTC', 'December 1972']
#   UID:  141f8a4599c6baad54ac2144a75ae7df

# %%
# ── Load model ───────────────────────────────────────────────────────────────
from engine import SemanticEngine, cal_flow, sum_normalize

print(f"Loading {MODEL_ID} (8bit={USE_8BIT})...")
engine = SemanticEngine(model_id=MODEL_ID, use_8bit=USE_8BIT)
NUM_LAYERS = engine.model.config.num_hidden_layers + 1
HIDDEN_DIM = engine.model.config.hidden_size
print(f"Model ready. {NUM_LAYERS} layers, {HIDDEN_DIM} hidden dim")
print(f"VRAM used: {torch.cuda.memory_allocated(0) / 1024**3:.1f} GB")
# Out:
# Loading Qwen/Qwen3-8B (8bit=True)...
# [Engine] Loading model: Qwen/Qwen3-8B
# [Engine] Using device: cuda:0 (NVIDIA GeForce RTX 3060)
# [Engine] VRAM available: 12.0 GB
# [Engine] Quantization enabled (8-bit: True)
# [Engine] Tokenizer loaded.
# Loading weights:   0%|          | 0/399 [00:00<?, ?it/s]
# [Engine] Model loaded. VRAM used: 8.8 GB
# Model ready. 37 layers, 4096 hidden dim
# VRAM used: 8.8 GB

# %%
# ── Helper functions ─────────────────────────────────────────────────────────

def cluster_assignment_entropy(clusters):
    sizes = [len(c) for c in clusters]
    n = sum(sizes)
    probs = [s / n for s in sizes]
    return -sum(p * math.log(p + 1e-10) for p in probs)

def extract_hidden_states(engine, prompt_text, answer_text):
    tokenizer, model = engine.tokenizer, engine.model
    messages = [{'role': 'user', 'content': prompt_text}]
    prompt_only = SemanticEngine._safe_apply_chat_template(
        tokenizer, messages, tokenize=False, add_generation_prompt=True)
    prompt_ids = tokenizer(prompt_only, return_tensors='pt').input_ids
    prompt_len = prompt_ids.shape[1]
    full_text = prompt_only + answer_text
    full_inputs = tokenizer(full_text, return_tensors='pt').to('cuda:0')
    full_len = full_inputs.input_ids.shape[1]
    if full_len <= prompt_len + 1:
        return None, None
    with torch.no_grad():
        outputs = model(**full_inputs, output_hidden_states=True)
    hidden = torch.stack(outputs.hidden_states, dim=0)[:, 0, :, :].float().cpu()
    tbg_hidden = hidden[:, prompt_len - 1, :].numpy()
    slt_hidden = hidden[:, full_len - 2, :].numpy()
    del outputs, hidden
    torch.cuda.empty_cache()
    return tbg_hidden, slt_hidden

def extract_logit_feats(generated_data_0):
    logits = np.array(generated_data_0['logits'])
    n = len(logits)
    if n == 0:
        return {'mean_chosen_logit': 0., 'min_chosen_logit': 0., 'std_chosen_logit': 0., 'answer_len': 0}
    return {'mean_chosen_logit': float(np.mean(logits)), 'min_chosen_logit': float(np.min(logits)),
            'std_chosen_logit': float(np.std(logits)), 'answer_len': n}

print("Helper functions defined.")
# Out:
# Helper functions defined.

# %%
# ── Record generation ────────────────────────────────────────────────────────

def generate_record(engine, example, num_samples=5):
    question, uid, refs = example['question'], get_uid(example), get_refs(example)
    gen_data = engine.generate_responses(question, num_samples=num_samples)
    main_answer = gen_data[0]['answer']
    clusters = engine.find_semantic_clusters(question, [d['answer'] for d in gen_data])
    mci = next(idx for idx, c in enumerate(clusters) if 0 in c)
    probs_se, logits_se = cal_flow([d['probs'] for d in gen_data], [d['logits'] for d in gen_data], clusters, fermi_mu=None)
    ce = sum_normalize(logits_se)
    tbg, slt = extract_hidden_states(engine, question, main_answer)
    return {
        'uid': uid, 'question': question, 'main_answer': main_answer,
        'correctness': correctness_fn(main_answer, refs),
        'energy_score_raw': ce[mci], 'entropy_score_raw': cluster_assignment_entropy(clusters),
        'energy_label': None, 'entropy_label': None,
        'emb_last_tok_before_gen': tbg, 'emb_tok_before_eos': slt,
        'logit_feats': extract_logit_feats(gen_data[0]),
        'token_ids': gen_data[0]['token_ids'],
        'num_clusters': len(clusters), 'cluster_sizes': [len(c) for c in clusters],
    }

print("generate_record defined.")
# Out:
# generate_record defined.

# %%
# ── Generation loop with checkpointing ───────────────────────────────────────
CKPT_PREFIX = f'checkpoint_*_{MODEL_SHORT}_benchmark_{EVAL_SHORT}.pkl'

existing_ckpts = sorted(glob.glob(os.path.join(DATA_DIR, CKPT_PREFIX)),
                        key=lambda p: int(re.search(r'checkpoint_(\d+)', p).group(1)))
records, start_idx = [], 0
if existing_ckpts:
    with open(existing_ckpts[-1], 'rb') as f: records = pickle.load(f)
    start_idx = len(records)
    print(f"Resuming from {start_idx}")
else:
    print("Starting fresh.")

errors = []
for i in tqdm(range(start_idx, actual_n), desc='Generating'):
    try:
        records.append(generate_record(engine, dataset_subset[i], NUM_SAMPLES))
    except Exception as e:
        print(f"\nERROR {i}: {e}")
        errors.append({'index': i, 'error': str(e)})
        continue
    if (i + 1) % CHECKPOINT_EVERY == 0:
        p = os.path.join(DATA_DIR, f'checkpoint_{i+1}_{MODEL_SHORT}_benchmark_{EVAL_SHORT}.pkl')
        with open(p, 'wb') as f: pickle.dump(records, f)
        print(f"\nSaved {p}")
print(f"Done. {len(records)} records, {len(errors)} errors")
# Out:
# Starting fresh.
# Generating:   0%|          | 0/200 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'output_logits', 'return_dict_in_generate', 'output_scores'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
#   [Sample 1/5] The last time anyone was on the moon was December 11, 1972, during the Apollo 17...
#   [Sample 2/5] The last time anyone was on the moon was December 11, 1972, during the Apollo 17...
#   [Sample 3/5] The last time anyone was on the moon was December 11, 1972, during the Apollo 17...
#   [Sample 4/5] The last time anyone was on the moon was December 11, 1972, during the Apollo 17...
#   [Sample 5/5] The last time anyone was on the moon was December 11, 1972, during the Apollo 17...
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   [Sample 1/5] The lyrics to "He Ain't Heavy, He's My Brother" were written by John Denver....
#   [Sample 2/5] The lyrics to "He Ain't Heavy, He's My Brother" were written by Tony Macaulay an...
#   [Sample 3/5] The lyrics to "He Ain't Heavy, He's My Brother" were written by Tony Macaulay an...
#   [Sample 4/5] The lyrics to "He Ain't Heavy, He's My Brother" were written by John Denver....
#   [Sample 5/5] The lyrics to "He Ain't Heavy, He's My Brother" were written by Tony Macaulay an...
#   [Sample 1/5] There are 3 seasons of *The Bastard Executioner*....
#   [Sample 2/5] There are 2 seasons of *The Bastard Executioner*....
#   [Sample 3/5] There are 3 seasons of *The Bastard Executioner*....
#   [Sample 4/5] There are 2 seasons of *The Bastard Executioner*....
#   [Sample 5/5] There are 2 seasons of *The Bastard Executioner*....
#   [Sample 1/5] The Eagles won their last Super Bowl on February 1, 2023, in Super Bowl LII....
#   [Sample 2/5] The Eagles won their last Super Bowl on February 1, 2023, in Super Bowl LII....
#   [Sample 3/5] The Eagles won their last Super Bowl on February 12, 2023....
#   [Sample 4/5] The Eagles won their last Super Bowl on February 1, 2023, in Super Bowl LVI....
#   [Sample 5/5] The Eagles won their last Super Bowl on February 12, 2018....
#   [Sample 1/5] The University of South Carolina won last year's NCAA Women's Basketball Champio...
#   [Sample 2/5] The University of Iowa won last year's NCAA Women's Basketball Championship....
#   [Sample 3/5] The University of South Carolina won last year's NCAA Women's Basketball Champio...
#   [Sample 4/5] The University of South Carolina won last year's NCAA Women's Basketball Champio...
#   [Sample 5/5] The University of Iowa won last year's NCAA Women's Basketball Championship....
#   [Sample 1/5] The Isle of Wight became an island during the last Ice Age, around 18,000 years ...
#   [Sample 2/5] The Isle of Wight became an island around 400,000 years ago....
#   [Sample 3/5] The Isle of Wight became an island around 400,000 years ago during the last Ice ...
#   [Sample 4/5] The Isle of Wight became an island during the last Ice Age, around 12,000 years ...
#   [Sample 5/5] The Isle of Wight became an island around 400,000 years ago....
#   [Sample 1/5] "Love Yourself" by Justin Bieber is about self-love and self-acceptance....
#   [Sample 2/5] "Love Yourself" by Justin Bieber is about self-love and personal growth....
#   [Sample 3/5] "Love Yourself" by Justin Bieber is about self-love and personal growth....
#   [Sample 4/5] "Love Yourself" by Justin Bieber is about self-love and personal growth....
#   [Sample 5/5] "Love Yourself" by Justin Bieber is about self-love and self-acceptance....
#   [Sample 1/5] James I...
#   [Sample 2/5] James I...
#   [Sample 3/5] James I...
#   [Sample 4/5] James I...
#   [Sample 5/5] James I...
#   [Sample 1/5] The Hot Coffee Mod in San Andreas is a mod that adds a mini-game where players c...
#   [Sample 2/5] The Hot Coffee Mod in San Andreas is a modification that allows players to acces...
#   [Sample 3/5] The Hot Coffee Mod in San Andreas is a modification that adds a hidden adult con...
#   [Sample 4/5] The Hot Coffee Mod in San Andreas is a modification that adds a hidden adult con...
#   [Sample 5/5] The Hot Coffee Mod in San Andreas is a modification that adds a hidden adult con...
#   [Sample 1/5] The maximum data rate for the 802.11a standard is 54 Mbps....
#   [Sample 2/5] The maximum data rate for the 802.11a standard is 54 Mbps....
#   [Sample 3/5] 54 Mbps...
#   [Sample 4/5] 54 Mbps...
#   [Sample 5/5] The maximum data rate for the 802.11a standard is 54 Mbps....
#   [Sample 1/5] Madhya Pradesh...
#   [Sample 2/5] Madhya Pradesh...
#   [Sample 3/5] Madhya Pradesh...
#   [Sample 4/5] Madhya Pradesh...
#   [Sample 5/5] Madhya Pradesh...
#   [Sample 1/5] The song "I Ran All the Way Home" was sung by The Beatles....
#   [Sample 2/5] The song "I Ran All the Way Home" was sung by The Beatles....
#   [Sample 3/5] The song "I Ran All the Way Home" was sung by The Beatles....
#   [Sample 4/5] The song "I Ran All the Way Home" was sung by The Beatles....
#   [Sample 5/5] The song "I Ran All the Way Home" was sung by The Beatles....
#   [Sample 1/5] The last name Wallace is of Scottish origin, derived from the place name "Wallac...
#   [Sample 2/5] The last name Wallace is of Scottish origin, derived from the place name "Wallac...
#   [Sample 3/5] The last name Wallace is of Scottish origin, derived from the place name "Wallac...
#   [Sample 4/5] The last name Wallace is of Scottish origin, derived from the Gaelic "Ua hAillea...
#   [Sample 5/5] The last name Wallace is of Scottish origin, derived from the place name "Wallac...
#   [Sample 1/5] Samuel L. Jackson...
#   [Sample 2/5] Samuel L. Jackson...
#   [Sample 3/5] Sam Waterston...
#   [Sample 4/5] Samuel L. Jackson...
#   [Sample 5/5] Sam Waterston...
#   [Sample 1/5] Jennifer Hudson....
#   [Sample 2/5] Jennifer Hudson....
#   [Sample 3/5] Jennifer Hudson....
#   [Sample 4/5] Jennifer Hudson...
#   [Sample 5/5] Jennifer Hudson....
#   [Sample 1/5] Leanna Walsmith plays Gram on The Young and the Restless....
#   [Sample 2/5] Liza Weil plays Gram on *The Young and the Restless*....
#   [Sample 3/5] Malia Baker plays Gram on *The Young and the Restless*....
#   [Sample 4/5] Lara Flynn Boyle plays Gram on The Young and the Restless....
#   [Sample 5/5] Lindsey Gort plays Gram on The Young and the Restless....
#   [Sample 1/5] The Oath of Allegiance....
#   [Sample 2/5] The oath that new citizens take is the Oath of Allegiance to the United States....
#   [Sample 3/5] The Oath of Allegiance....
#   [Sample 4/5] The Oath of Allegiance....
#   [Sample 5/5] The Oath of Allegiance....
#   [Sample 1/5] Anakin Skywalker...
#   [Sample 2/5] Anakin Skywalker...
#   [Sample 3/5] Anakin Skywalker...
#   [Sample 4/5] Anakin Skywalker...
#   [Sample 5/5] Anakin Skywalker...
#   [Sample 1/5] There is no record in the Bible of anyone having a baby at the age of 100....
#   [Sample 2/5] There is no record in the Bible of anyone having a baby at the age of 100....
#   [Sample 3/5] There is no record of anyone having a baby at 100 in the Bible....
#   [Sample 4/5] There is no record of anyone having a baby at 100 in the Bible....
#   [Sample 5/5] No one had a baby at 100 in the Bible....
#   [Sample 1/5] The age requirement to buy a BB gun varies by location, but in the United States...
#   [Sample 2/5] The age requirement to buy a BB gun varies by location, but in the United States...
#   [Sample 3/5] The age requirement to buy a BB gun varies by location, but in the United States...
#   [Sample 4/5] The age requirement to buy a BB gun varies by location, but in the United States...
#   [Sample 5/5] The age requirement to buy a BB gun varies by location, but in the United States...
#   [Sample 1/5] Yes, Ethiopian Airlines Flight 961 crashed into the Indian Ocean on November 25,...
#   [Sample 2/5] Yes, Ethiopian Airlines Flight 961 crashed into the Indian Ocean on November 25,...
#   [Sample 3/5] Yes, Ethiopian Airlines Flight 961 crashed into the Indian Ocean on November 25,...
#   [Sample 4/5] Yes, Ethiopian Airlines Flight 961 crashed into the Indian Ocean on November 25,...
#   [Sample 5/5] Yes, Ethiopian Airlines Flight 961 crashed into the Indian Ocean on November 25,...
#   [Sample 1/5] "Percy Jackson & the Olympians" was primarily filmed in New York City, with some...
#   [Sample 2/5] "Where was Percy Jackson and the Olympians filmed?" is a question that can be an...
#   [Sample 3/5] "Percy Jackson & the Olympians" was filmed in various locations, including New Y...
#   [Sample 4/5] The series *Percy Jackson & the Olympians* was primarily filmed in Vancouver, Br...
#   [Sample 5/5] Percy Jackson & the Olympians was filmed in various locations, including Vancouv...
#   [Sample 1/5] There are 8 seasons of Vampire Diaries....
#   [Sample 2/5] There are 8 seasons of Vampire Diaries....
#   [Sample 3/5] There are 8 seasons of Vampire Diaries....
#   [Sample 4/5] There are 8 seasons of Vampire Diaries....
#   [Sample 5/5] There are 8 seasons of Vampire Diaries....
#   [Sample 1/5] There are 291 episodes in Dragon Ball Z....
#   [Sample 2/5] There are 291 episodes in Dragon Ball Z....
#   [Sample 3/5] There are 291 episodes in Dragon Ball Z....
#   [Sample 4/5] There are 291 episodes in Dragon Ball Z....
#   [Sample 5/5] There are 291 episodes in Dragon Ball Z....
#   [Sample 1/5] Jacob Tremblay...
#   [Sample 2/5] Jacob Tremblay...
#   [Sample 3/5] Jacob Tremblay...
#   [Sample 4/5] Jacob Tremblay...
#   [Sample 5/5] Jacob Tremblay...
#   [Sample 1/5] The first Australian Prime Minister, Sir Edmund Barton, was elected in 1901....
#   [Sample 2/5] The first Australian Prime Minister, Sir Edmund Barton, was elected in 1901....
#   [Sample 3/5] The first Australian Prime Minister, Sir Edmund Barton, was elected in 1901....
#   [Sample 4/5] The first Australian Prime Minister, Sir Edmund Barton, was elected in 1901....
#   [Sample 5/5] The first Australian Prime Minister, Sir Edmund Barton, was elected in 1901....
#   [Sample 1/5] Timothée Chalamet plays Matthew on *Anne with an E*....
#   [Sample 2/5] Matthew is played by actor Timothée Chalamet in *Anne with an E*....
#   [Sample 3/5] Matthew is played by Timothée Chalamet in *Anne with an E*....
#   [Sample 4/5] Matthew is played by Timothée Chalamet in *Anne with an E*....
#   [Sample 5/5] Matthew is played by Jacob Tremblay in *Anne with an E*....
#   [Sample 1/5] The girl in "21 Guns" by Green Day is a fictional character representing the ide...
#   [Sample 2/5] The girl in "21 Guns" by Green Day is a symbolic representation of the loss of i...
#   [Sample 3/5] The girl in "21 Guns" by Green Day is a fictional character representing the los...
#   [Sample 4/5] The girl in "21 Guns" by Green Day is a fictional character and not based on a r...
#   [Sample 5/5] The girl in "21 Guns" by Green Day is a fictional character representing the los...
#   [Sample 1/5] Heath Ledger...
#   [Sample 2/5] Heath Ledger...
#   [Sample 3/5] Heath Ledger...
#   [Sample 4/5] Heath Ledger...
#   [Sample 5/5] Heath Ledger...
#   [Sample 1/5] The South Asian Association for Regional Cooperation (SAARC) was formed on Decem...
#   [Sample 2/5] The South Asian Association for Regional Cooperation (SAARC) was formed in 1985....
#   [Sample 3/5] The South Asian Association for Regional Cooperation (SAARC) was formed in 1985....
#   [Sample 4/5] The South Asian Association for Regional Cooperation (SAARC) was formed in 1985....
#   [Sample 5/5] The South Asian Association for Regional Cooperation (SAARC) was formed in 1985....
#   [Sample 1/5] The first *Hunger Games* book was published on September 14, 2008....
#   [Sample 2/5] The first *Hunger Games* book was published on September 14, 2008....
#   [Sample 3/5] The first *Hunger Games* book was published in 2008....
#   [Sample 4/5] The first *Hunger Games* book was published on September 14, 2008....
#   [Sample 5/5] The first *Hunger Games* book was published on September 14, 2008....
#   [Sample 1/5] Bette Midler portrayed Rose DeWitt Bukater in the film *Titanic*....
#   [Sample 2/5] Bette Midler portrayed Rose DeWitt Bukater in the movie *Titanic*....
#   [Sample 3/5] Bette Midler portrayed Rose DeWitt Bukater in the movie *Titanic*....
#   [Sample 4/5] Bette Midler portrayed Rose DeWitt Bukater in the film *Titanic*....
#   [Sample 5/5] Bette Midler portrayed Rose DeWitt Bukater in the film *Titanic*....
#   [Sample 1/5] Dave Gahan...
#   [Sample 2/5] Dave Gahan...
#   [Sample 3/5] Dave Gahan...
#   [Sample 4/5] Martin Gore...
#   [Sample 5/5] Dave Gahan...
#   [Sample 1/5] The butchers in the *Slaughterhouse Cases* (1873) lived in Louisiana....
#   [Sample 2/5] The butchers in the *Slaughterhouse Cases* lived in Louisiana....
#   [Sample 3/5] The butchers in the *Slaughterhouse Cases* (1873) lived in Louisiana....
#   [Sample 4/5] The butchers in the *Slaughterhouse Cases* lived in Louisiana....
#   [Sample 5/5] The butchers in the *Slaughterhouse Cases* lived in Louisiana....
#   [Sample 1/5] W. Edward Deming and Joseph M. Juran....
#   [Sample 2/5] W. Edwards Deming and Joseph M. Juran are widely recognized as the developers of...
#   [Sample 3/5] W. Edwards Deming and Joseph M. Juran are considered the primary developers of t...
#   [Sample 4/5] W. Edwards Deming and Joseph M. Juran are widely recognized as the key developer...
#   [Sample 5/5] W. Edwards Deming and Joseph M. Juran are considered the primary developers of t...
#   [Sample 1/5] Katy Perry...
#   [Sample 2/5] Karen Poole and Diane Warren....
#   [Sample 3/5] Taylor Swift wrote the lyrics to "Can't Get You Out of My Head."...
#   [Sample 4/5] Kylie Minogue wrote the lyrics for "Can't Get You Out of My Head."...
#   [Sample 5/5] Katy Perry...
#   [Sample 1/5] The anime "No Game, No Life" ends with the protagonists, Sora and Shizuku, becom...
#   [Sample 2/5] The anime *No Game, No Life* ends with the protagonists, Sora and Shiro, becomin...
#   [Sample 3/5] The anime *No Game, No Life* ends after the main story arc, which concludes in t...
#   [Sample 4/5] The anime *No Game, No Life* ends after the main story arc, which concludes in t...
#   [Sample 5/5] The anime "No Game, No Life" ends after the main story arc, with the protagonist...
#   [Sample 1/5] Taylor Swift's first album, *Taylor Swift*, was released on October 24, 2006....
#   [Sample 2/5] Taylor Swift's first album, *Taylor Swift*, was released on October 24, 2006....
#   [Sample 3/5] Taylor Swift's first album, *Taylor Swift*, was released on October 24, 2006....
#   [Sample 4/5] Taylor Swift's first album, *Taylor Swift*, was released on October 24, 2006....
#   [Sample 5/5] Taylor Swift's first album, *Taylor Swift*, was released on October 24, 2006....
#   [Sample 1/5] The three *Fifty Shades of Grey* books are *Fifty Shades of Grey*, *Fifty Shades...
#   [Sample 2/5] The three *Fifty Shades of Grey* books are *Fifty Shades of Grey*, *Fifty Shades...
#   [Sample 3/5] The three *Fifty Shades of Grey* books are *Fifty Shades of Grey*, *Fifty Shades...
#   [Sample 4/5] The three *Fifty Shades of Grey* books are *Fifty Shades of Grey*, *Fifty Shades...
#   [Sample 5/5] The three *Fifty Shades of Grey* books are *Fifty Shades of Grey*, *Fifty Shades...
#   [Sample 1/5] The judiciary, specifically judges, have the power to make decisions in courts o...
#   [Sample 2/5] The judicial power to make decisions in courts of law is held by judges....
#   [Sample 3/5] The judiciary, specifically judges, have the power to make decisions in courts o...
#   [Sample 4/5] The judicial power to make decisions in courts of law is held by judges....
#   [Sample 5/5] The judiciary, specifically judges, have the power to make decisions in courts o...
#   [Sample 1/5] The ranks in the U.S. Navy, from lowest to highest, are:
# Seaman, Seaman Recrui...
#   [Sample 2/5] The ranks in the U.S. Navy are: Seaman Recruit, Seaman, Seaman Apprentice, Seama...
#   [Sample 3/5] The ranks in the U.S. Navy include: Seaman, Petty Officer, Chief, Officer, and A...
#   [Sample 4/5] The ranks in the U.S. Navy include:
# - Enlisted: Seaman, Petty Officer, Chief, ...
#   [Sample 5/5] The ranks in the U.S. Navy, from lowest to highest, are:
# Seaman, Seaman Appren...
#   [Sample 1/5] Alhazen...
#   [Sample 2/5] Alhazen...
#   [Sample 3/5] Alhazen...
#   [Sample 4/5] Abu Bakr al-Khwarizmi...
#   [Sample 5/5] Alhazen...
#   [Sample 1/5] The coach for the Ottawa Senators is John Hynes....
#   [Sample 2/5] The coach for the Ottawa Senators is John Hynes....
#   [Sample 3/5] As of 2023, the head coach for the Ottawa Senators is John Hynes....
#   [Sample 4/5] The coach for the Ottawa Senators is Jon Cooper....
#   [Sample 5/5] As of the latest information, the head coach for the Ottawa Senators is John Hyn...
#   [Sample 1/5] The last episode of *What Happens to My Family?* is Season 1, Episode 6, titled ...
#   [Sample 2/5] The last episode of *What Happens to My Family?* is Season 1, Episode 6, titled ...
#   [Sample 3/5] The last episode of *What Happens to My Family?* is Season 1, Episode 6, titled ...
#   [Sample 4/5] The last episode of *What Happens to My Family?* is Season 3, Episode 6, titled ...
#   [Sample 5/5] The last episode of *What Happens to My Family?* is Season 2, Episode 6, titled ...
#   [Sample 1/5] The Vikings have never been in the NFC Championship game. They are based in the ...
#   [Sample 2/5] The Vikings have never been in the NFC Championship game....
#   [Sample 3/5] The Vikings have never been in the NFC Championship game. They are a team in the...
#   [Sample 4/5] The Vikings have never been in the NFC Championship game....
#   [Sample 5/5] The Vikings have never been in the NFC Championship game. They are a team in the...
#   [Sample 1/5] The Netherlands flag has three horizontal stripes: red, white, and blue....
#   [Sample 2/5] The Netherlands flag has three horizontal stripes: red, white, and blue....
#   [Sample 3/5] The Netherlands flag has three horizontal stripes: red, white, and blue....
#   [Sample 4/5] The Netherlands flag has three horizontal stripes: red, white, and blue....
#   [Sample 5/5] The Netherlands flag has three horizontal stripes: red, white, and blue....
#   [Sample 1/5] Matthew 6:9-13 and Luke 11:2-4...
#   [Sample 2/5] The Lord's Prayer is found in the Bible in Matthew 6:9-13 and Luke 11:1-4....
#   [Sample 3/5] The Lord's Prayer is found in the Bible in Matthew 6:9-13 and Luke 11:1-4....
#   [Sample 4/5] The Lord's Prayer is found in the Bible in Matthew 6:9-13 and Luke 11:1-4....
#   [Sample 5/5] The Lord's Prayer is found in the Bible in Matthew 6:9-13 and Luke 11:2-4....
#   [Sample 1/5] The last time Oklahoma won a national championship in football was in 2021....
#   [Sample 2/5] The last time Oklahoma won a national championship in football was in 2021....
#   [Sample 3/5] The last time Oklahoma won a national championship in football was in 2021....
#   [Sample 4/5] The last time Oklahoma won a national championship in football was in 2021....
#   [Sample 5/5] The last time Oklahoma won a national championship in football was in 2021....
#   [Sample 1/5] The Ten Commandments are found in Exodus 20:1-17 in the Bible....
#   [Sample 2/5] The Ten Commandments are found in Exodus 20:1-17 in the Bible....
#   [Sample 3/5] The Ten Commandments are found in Exodus 20:1-17 in the Bible....
#   [Sample 4/5] The Ten Commandments are found in Exodus 20:1-17 in the Bible....
#   [Sample 5/5] The Ten Commandments are found in Exodus 20:1-17 in the Bible....
#   [Sample 1/5] The Allies moved to Southern Europe, invading Sicily in July 1943....
#   [Sample 2/5] The Allies moved to Sicily....
#   [Sample 3/5] The Allies moved to Italy....
#   [Sample 4/5] The Allies moved to Sicily....
#   [Sample 5/5] The Allies moved to southern Europe, landing in Sicily as part of the Italian Ca...
#
# Saved d:\Github Repositories\SemanticEnergy\backend\data\checkpoint_50_qwen3-8b_benchmark_nqopen.pkl
#   [Sample 1/5] The name Veronica means "true image" or "faithful image" in English. It is deriv...
#   [Sample 2/5] The name Veronica means "true image" or "faithful image" in English. It is deriv...
#   [Sample 3/5] The name Veronica means "true image" or "faithful image" in English. It is deriv...
#   [Sample 4/5] Veronica is a name of Latin origin meaning "true image" or "faithful image." It ...
#   [Sample 5/5] The name Veronica means "true image" or "faithful image" in English. It is deriv...
#   [Sample 1/5] The aorta....
#   [Sample 2/5] The aorta....
#   [Sample 3/5] The aorta....
#   [Sample 4/5] The aorta....
#   [Sample 5/5] The aorta....
#   [Sample 1/5] Michael Landon Jr....
#   [Sample 2/5] Michael Lerner played Solomon in Little House on the Prairie....
#   [Sample 3/5] Michael Landon Jr....
#   [Sample 4/5] Michael Landon Jr....
#   [Sample 5/5] Melody Thomas is the actor who played Solomon in Little House on the Prairie....
#   [Sample 1/5] Eric ends up with Debra....
#   [Sample 2/5] Eric ends up with Jackie....
#   [Sample 3/5] Eric ends up with Donna....
#   [Sample 4/5] Eric ends up with Jackie....
#   [Sample 5/5] Eric ends up with Donna....
#   [Sample 1/5] rotating....
#   [Sample 2/5] rotating....
#   [Sample 3/5] rotating....
#   [Sample 4/5] rotating....
#   [Sample 5/5] rotating....
#   [Sample 1/5] Rib vaults in Gothic architecture, such as those found in Notre-Dame de Paris an...
#   [Sample 2/5] Rib vaults in structures like Wells Cathedral are formed by intersecting arched ...
#   [Sample 3/5] Rib vaults in structures like Notre-Dame de Paris and Wells Cathedral are formed...
#   [Sample 4/5] Rib vaults in structures like Wells Cathedral are formed by intersecting arched ...
#   [Sample 5/5] Rib vaults in structures like Wells Cathedral are formed by intersecting arched ...
#   [Sample 1/5] The song "Good Morning, Good Morning" was sung by The Beatles....
#   [Sample 2/5] The song "Good Morning, Good Morning" was sung by The Animals....
#   [Sample 3/5] The song "Good Morning, Good Morning" was sung by The Spencer Davis Group....
#   [Sample 4/5] The song "Good Morning, Good Morning" was sung by The Mamas & The Papas....
#   [Sample 5/5] The song "Good Morning, Good Morning" was sung by The Jimi Hendrix Experience....
#   [Sample 1/5] The song "Papa Got a Brand New Bag" was written by Arthur Jacobson....
#   [Sample 2/5] The song "Papa Got a Brand New Bag" was written by Bob Dylan....
#   [Sample 3/5] The song "Papa Got a Brand New Bag" was written by Arthur Alexander....
#   [Sample 4/5] The song "Papa Got a Brand New Bag" was written by Arthur Hamilton....
#   [Sample 5/5] The song "Papa Got a Brand New Bag" was written by Arthur Alexander....
#   [Sample 1/5] Roadrunners live in the deserts of the southwestern United States and northweste...
#   [Sample 2/5] Roadrunners live in the deserts of the southwestern United States and northweste...
#   [Sample 3/5] Roadrunners live in the deserts of the southwestern United States and northweste...
#   [Sample 4/5] Roadrunners live in the deserts of the southwestern United States and northweste...
#   [Sample 5/5] Roadrunners live in the deserts of the southwestern United States and northweste...
#   [Sample 1/5] The song "It's a Long Long Way to Pasadena" was written by Bob Dylan....
#   [Sample 2/5] The song "It's a Long, Long Way to Pasadena" was written by Paul McCartney and J...
#   [Sample 3/5] The song "It's a Long, Long Way to Pasadena" was written by Paul McCartney and J...
#   [Sample 4/5] The song "It's a Long, Long Way to Pasadena" was written by Frank Loesser....
#   [Sample 5/5] John Denver...
#   [Sample 1/5] There is no dog in Tom and Jerry; the main characters are Tom (the cat) and Jerr...
#   [Sample 2/5] There is no dog in the Tom and Jerry cartoons. The main characters are Tom (the ...
#   [Sample 3/5] There is no dog in the Tom and Jerry cartoons. The main characters are Tom (the ...
#   [Sample 4/5] There is no dog in Tom and Jerry; the main characters are Tom (the cat) and Jerr...
#   [Sample 5/5] There is no dog in Tom and Jerry; the main characters are Tom the cat and Jerry ...
#   [Sample 1/5] The nominee for President of India in 2017 was Venkaiah Naidu, who was elected o...
#   [Sample 2/5] The candidates nominated for the presidential election in India in 2017 were:
#
# 1...
#   [Sample 3/5] The President of India in 2017 was Shri Pranab Mukherjee, who was re-elected for...
#   [Sample 4/5] The 2017 Indian presidential election did not have any official nominations for ...
#   [Sample 5/5] The President of India in 2017 was Shri Narendra Modi, who was re-elected for a ...
#   [Sample 1/5] The Path train stops at Newark Liberty International Airport (EWR) and Newark Pe...
#   [Sample 2/5] The Path train stops at Newark Liberty International Airport (EWR) and Newark Br...
#   [Sample 3/5] The Path train stops at Newark Liberty International Airport (EWR) and Newark Pe...
#   [Sample 4/5] The Path train stops at Newark Penn Station....
#   [Sample 5/5] The Path train stops at Newark Liberty International Airport (EWR) and Newark Pe...
#   [Sample 1/5] Route 66 starts in Chicago, Illinois, on the east coast, and ends in Santa Monic...
#   [Sample 2/5] Route 66 starts in Santa Monica, California on the west coast....
#   [Sample 3/5] Route 66 starts in Santa Monica, California on the west coast....
#   [Sample 4/5] Route 66 starts in Santa Monica, California on the west coast....
#   [Sample 5/5] Route 66 starts in Santa Monica, California on the west coast....
#   [Sample 1/5] The first wife on *Sister Wives* is Meri Brown....
#   [Sample 2/5] The first wife on *Sister Wives* is Meri Brown....
#   [Sample 3/5] The first wife on *Sister Wives* is Meri Brown....
#   [Sample 4/5] The first wife on *Sister Wives* is Meri Brown....
#   [Sample 5/5] The first wife on *Sister Wives* is Meri Brown....
#   [Sample 1/5] The Houston Astros joined the American League in 2013....
#   [Sample 2/5] The Houston Astros joined the American League in 2013....
#   [Sample 3/5] The Houston Astros joined the American League in 2013....
#   [Sample 4/5] The Houston Astros joined the American League in 2013....
#   [Sample 5/5] The Houston Astros joined the American League in 2013....
#   [Sample 1/5] Cigarette advertising was banned on television in the United States in 1971....
#   [Sample 2/5] Cigarette advertising was banned on television in the United States in 1971....
#   [Sample 3/5] Cigarette advertising was banned on television in the United States in 1971....
#   [Sample 4/5] Cigarette advertising was banned on television in the United States in 1971....
#   [Sample 5/5] Cigarette advertising was banned on television in the United States in 1971....
#   [Sample 1/5] "Fix You" is a song by Coldplay from their album *Viva La Vida or Death and All ...
#   [Sample 2/5] "Fix You" is a song by Coldplay from their album *Viva la Vida or Death and All ...
#   [Sample 3/5] "Fix You" is a song by Coldplay from their album *Viva la Vida or Death and All ...
#   [Sample 4/5] "Fix You" is a song by Coldplay from their album *Viva la Vida or Death and All ...
#   [Sample 5/5] The song "I Will Try to Fix You" by Coldplay is from their 2011 album *Mylo Xylo...
#   [Sample 1/5] radians...
#   [Sample 2/5] radians...
#   [Sample 3/5] radians...
#   [Sample 4/5] radians...
#   [Sample 5/5] radians...
#   [Sample 1/5] the oligodynamic effect is a phenomenon that describes the antimicrobial activit...
#   [Sample 2/5] the oligodynamic effect is a phenomenon that describes the antimicrobial action ...
#   [Sample 3/5] the oligodynamic effect is a phenomenon that describes the antimicrobial activit...
#   [Sample 4/5] the oligodynamic effect is a phenomenon that describes the antimicrobial propert...
#   [Sample 5/5] the oligodynamic effect is a phenomenon that describes the antimicrobial action ...
#   [Sample 1/5] The White Witch lives in the land of Winter, which is located to the north of Na...
#   [Sample 2/5] The White Witch lives in the Frozen North of Narnia....
#   [Sample 3/5] The White Witch lives in the North, in a place called the Cair Paravel....
#   [Sample 4/5] The White Witch lives in the far north of Narnia, in a place called the Frozen N...
#   [Sample 5/5] The White Witch lives in the North, in a place called the Frozen North....
#   [Sample 1/5] As of the 2023-2024 season, the UConn Women's Basketball team has won 121 games ...
#   [Sample 2/5] As of the 2023-2024 season, the UConn women's basketball team has won 111 games ...
#   [Sample 3/5] As of the 2023-2024 season, the UConn Women's Basketball team has won 111 games ...
#   [Sample 4/5] As of the most recent update in 2023, the UConn Women's Basketball team has won ...
#   [Sample 5/5] As of the 2023-2024 season, the UConn women's basketball team has won 121 games ...
#   [Sample 1/5] The at symbol is also known as the "at sign."...
#   [Sample 2/5] Yes, the at symbol is also called the "at sign."...
#   [Sample 3/5] The at symbol is called the "at sign."...
#   [Sample 4/5] The at symbol is also known as the "at sign."...
#   [Sample 5/5] The at symbol is called the "at sign."...
#   [Sample 1/5] The theme song for the TV show *Cops* is performed by The J. Geils Band....
#   [Sample 2/5] The theme song for the TV show *Cops* is performed by The S.O.S. Band....
#   [Sample 3/5] The theme song for the TV show *COPS* is performed by The S.O.S. Band....
#   [Sample 4/5] The theme song for the TV show *Cops* is performed by The Troggs....
#   [Sample 5/5] The theme song for the TV show *Cops* is performed by The Raspberries....
#   [Sample 1/5] Corporal punishment was banned in South Africa in 1997....
#   [Sample 2/5] Corporal punishment was banned in South Africa in 1997....
#   [Sample 3/5] Corporal punishment was banned in South Africa in 1998....
#   [Sample 4/5] Corporal punishment was banned in South Africa in 1998....
#   [Sample 5/5] Corporal punishment was banned in South Africa in 1998....
#   [Sample 1/5] Joonas Suotamo...
#   [Sample 2/5] Gwendoline Christie...
#   [Sample 3/5] Joonas Suotamo...
#   [Sample 4/5] Gwendoline Christie...
#   [Sample 5/5] Gwendoline Christie...
#   [Sample 1/5] The song "She's Like the Wind" is performed by The Beatles....
#   [Sample 2/5] The song "She's Like the Wind" is performed by The Beatles....
#   [Sample 3/5] The song "She's Like the Wind" is sung by Shakin' Stevens....
#   [Sample 4/5] The song "She's Like the Wind" is performed by The Beatles....
#   [Sample 5/5] The song "She's Like the Wind" is performed by The Beatles....
#   [Sample 1/5] Marathon changed its name to Snickers in 1995....
#   [Sample 2/5] The Marathon changed its name to Snickers in 1993....
#   [Sample 3/5] Marathon changed its name to Snickers in 1993....
#   [Sample 4/5] The marathon changed its name to Snickers in 2002....
#   [Sample 5/5] Marathon changed its name to Snickers in 1991....
#   [Sample 1/5] Bartholomeu Dias...
#   [Sample 2/5] Bartolomeu Dias...
#   [Sample 3/5] Bartholomew Dias...
#   [Sample 4/5] Diniz Dias...
#   [Sample 5/5] Bartholomew Dias...
#   [Sample 1/5] The Forbidden City was ordered to be built by the Ming Dynasty emperor Yongle....
#   [Sample 2/5] The Forbidden City was ordered to be built by the Ming Dynasty Emperor Yongle....
#   [Sample 3/5] The Forbidden City was ordered to be built by the Ming Dynasty's third emperor, ...
#   [Sample 4/5] The Forbidden City was ordered to be built by the Ming Dynasty's third emperor, ...
#   [Sample 5/5] The Forbidden City was ordered to be built by the Ming Dynasty emperor Zhu Di (a...
#   [Sample 1/5] The song "Let Me Tell You About the Birds and the Bees" was sung by The Beatles....
#   [Sample 2/5] The song "Let Me Tell You About the Birds and the Bees" was sung by The Beatles....
#   [Sample 3/5] The song "Let Me Tell You About the Birds and the Bees" was originally performed...
#   [Sample 4/5] The song "Let Me Tell You About the Birds and the Bees" was sung by The Beatles....
#   [Sample 5/5] The song "Let Me Tell You About the Birds and the Bees" was sung by The Beatles....
#   [Sample 1/5] The president has the power to approve or veto legislation....
#   [Sample 2/5] The President has the power to approve or veto legislation....
#   [Sample 3/5] The President has the power to approve or veto legislation....
#   [Sample 4/5] The President has the power to approve or veto legislation....
#   [Sample 5/5] The President has the power to approve or veto legislation....
#   [Sample 1/5] There are 12 seasons of The Rugrats....
#   [Sample 2/5] There are 11 seasons of The Rugrats....
#   [Sample 3/5] There are 11 seasons of The Rugrats....
#   [Sample 4/5] There are 10 seasons of The Rugrats....
#   [Sample 5/5] There are 11 seasons of The Rugrats....
#   [Sample 1/5] As of the latest available information, the Minister of Local Government in Zimb...
#   [Sample 2/5] As of the latest available information, the Minister of Local Government in Zimb...
#   [Sample 3/5] As of the latest available information, the Minister of Local Government in Zimb...
#   [Sample 4/5] As of the latest available information, the Minister of Local Government in Zimb...
#   [Sample 5/5] As of the latest available information, the Minister of Local Government in Zimb...
#   [Sample 1/5] The initial effect was economic hardship, including inflation, unemployment, and...
#   [Sample 2/5] The initial effect was economic instability, including hyperinflation, unemploym...
#   [Sample 3/5] The initial effect was economic instability, including hyperinflation, unemploym...
#   [Sample 4/5] The initial effect was economic decline, characterized by hyperinflation, unempl...
#   [Sample 5/5] The initial effect was economic instability, including hyperinflation, unemploym...
#   [Sample 1/5] Toyota started making cars in the United States in 1988 with the opening of its ...
#   [Sample 2/5] Toyota started making cars in the US in 1988 with the opening of its first U.S. ...
#   [Sample 3/5] Toyota started making cars in the United States in 1988 with the opening of its ...
#   [Sample 4/5] Toyota started making cars in the United States in 1988 with the opening of its ...
#   [Sample 5/5] Toyota started making cars in the United States in 1988 with the opening of its ...
#   [Sample 1/5] A Terry's Chocolate Orange typically contains 32 pieces of chocolate....
#   [Sample 2/5] A Terry's Chocolate Orange typically contains 32 pieces....
#   [Sample 3/5] A Terry's Chocolate Orange typically contains 32 pieces of chocolate....
#   [Sample 4/5] A Terry's Chocolate Orange typically contains 40 pieces of chocolate....
#   [Sample 5/5] A Terry's Chocolate Orange typically contains 40 pieces of chocolate....
#   [Sample 1/5] Dominic Cooper plays the Saint of Killers on *Preacher*....
#   [Sample 2/5] Dominic Cooper plays the Saint of Killers on *Preacher*....
#   [Sample 3/5] Dominic West plays the Saint of Killers on Preacher....
#   [Sample 4/5] Dominic Cooper plays the Saint of Killers in *Preacher*....
#   [Sample 5/5] Dominic Cooper plays the Saint of Killers on *Preacher*....
#   [Sample 1/5] The Royal Proclamation of 1763 ended with the American Revolution in 1776....
#   [Sample 2/5] The Royal Proclamation of 1763 remained in effect until the British North Americ...
#   [Sample 3/5] The Royal Proclamation of 1763 ended with the American Revolution in 1776....
#   [Sample 4/5] The Royal Proclamation of 1763 ended with the American Revolution in 1776....
#   [Sample 5/5] The Royal Proclamation of 1763 ended with the American Revolution in 1776....
#   [Sample 1/5] Beyoncé performed the halftime show at Super Bowl 2016....
#   [Sample 2/5] Beyoncé performed the halftime show at Super Bowl 2016....
#   [Sample 3/5] Beyoncé performed the halftime show at Super Bowl 2016....
#   [Sample 4/5] Beyoncé performed the halftime show at Super Bowl 2016....
#   [Sample 5/5] Beyoncé performed the halftime show at Super Bowl 2016....
#   [Sample 1/5] "Johnny Cash: One Piece at a Time" is a song by Johnny Cash, released in 1969. I...
#   [Sample 2/5] "Johnny Cash One Piece at a Time" is a song by Johnny Cash, released in 1969. It...
#   [Sample 3/5] "Johnny Cash: One Piece at a Time" is a 2012 documentary film that explores the ...
#   [Sample 4/5] "Johnny Cash One Piece at a Time" is a song by Johnny Cash, released in 1969. It...
#   [Sample 5/5] "Johnny Cash: One Piece at a Time" is a 2012 documentary film that explores the ...
#   [Sample 1/5] As of 2023, the minimum wage in France is €12.05 per hour for employees aged 18 ...
#   [Sample 2/5] As of 2023, the minimum wage in France is 10.52 euros per hour....
#   [Sample 3/5] As of 2023, the minimum wage in France is €12.05 per hour for the first 35 hours...
#   [Sample 4/5] As of 2023, the minimum wage in France is €12.05 per hour for employees over 18 ...
#   [Sample 5/5] As of 2023, the minimum wage in France is 10.55 euros per hour for employees age...
#   [Sample 1/5] 1. **Vascular Spasm**: Blood vessels constrict to reduce blood loss.
# 2. **Plat...
#   [Sample 2/5] 1. **Vascular Spasm**: Blood vessels constrict to reduce blood flow.
# 2. **Plat...
#   [Sample 3/5] 1. **Vasoconstriction**: Blood vessels constrict to reduce blood flow.
# 2. **Pl...
#   [Sample 4/5] 1. **Vascular Spasm**: Blood vessels constrict to reduce blood flow.
# 2. **Plat...
#   [Sample 5/5] 1. **Vasoconstriction**: Blood vessels constrict to reduce blood flow.
# 2. **Pl...
#   [Sample 1/5] *Amnesia: The Dark Descent* was released on October 28, 2010....
#   [Sample 2/5] *Amnesia: The Dark Descent* was released on **October 28, 2010**....
#   [Sample 3/5] *Amnesia: The Dark Descent* was released on **October 28, 2010**....
#   [Sample 4/5] *Amnesia: The Dark Descent* was released on **April 29, 2010**....
#   [Sample 5/5] *Amnesia: The Dark Descent* was released on **April 28, 2010**....
#   [Sample 1/5] The oldest street in the Philippines is Calle Real, located in Intramuros, Manil...
#   [Sample 2/5] The oldest street in the Philippines is Calle Real, located in Intramuros, Manil...
#   [Sample 3/5] The oldest street in the Philippines is Calle Real, located in Intramuros, Manil...
#   [Sample 4/5] The oldest street in the Philippines is Calle Real, located in Vigan City, Iloco...
#   [Sample 5/5] The oldest street in the Philippines is Calle Real, located in Vigan City, Iloco...
#   [Sample 1/5] The tibia and fibula are located in the lower leg, with the tibia on the medial ...
#   [Sample 2/5] The tibia and fibula are located in the lower leg, with the tibia on the medial ...
#   [Sample 3/5] The tibia and fibula are located in the lower leg, with the tibia on the medial ...
#   [Sample 4/5] The tibia and fibula are located in the lower leg, with the tibia on the medial ...
#   [Sample 5/5] The tibia and fibula are located in the lower leg, with the tibia on the medial ...
#   [Sample 1/5] Lee Marvin played Bat Masterson in the TV series....
#   [Sample 2/5] Dean Jagger played Bat Masterson in the TV series....
#   [Sample 3/5] Rock Hudson played Bat Masterson in the TV series....
#   [Sample 4/5] Lee Marvin played Bat Masterson in the TV series....
#   [Sample 5/5] Lee Majors played Bat Masterson in the TV series....
#   [Sample 1/5] The song "Sugar Sugar" featuring the line "You are my candy girl" is performed b...
#   [Sample 2/5] The song "Sugar Sugar" is performed by The Archies, but the line "you are my can...
#   [Sample 3/5] The song "Sugar Sugar" is performed by The Archies, and the line "you are my can...
#   [Sample 4/5] The song "Sugar Sugar" is performed by The Archies, and "You Are My Candy Girl" ...
#   [Sample 5/5] The song "Sugar Sugar" is performed by The Archies, but the line "you are my can...
#   [Sample 1/5] Alpine skiing, cross-country skiing, freestyle skiing, ski jumping, and Nordic c...
#   [Sample 2/5] Alpine skiing, cross-country skiing, ski jumping, freestyle skiing, and snowboar...
#   [Sample 3/5] Alpine skiing, cross-country skiing, ski jumping, freestyle skiing, and snowboar...
#   [Sample 4/5] Alpine skiing, cross-country skiing, ski jumping, freestyle skiing, and snowboar...
#   [Sample 5/5] Alpine skiing, cross-country skiing, ski jumping, freestyle skiing, and snowboar...
#   [Sample 1/5] Jason Thompson...
#   [Sample 2/5] Jesse Spencer...
#   [Sample 3/5] Joshua Morrow...
#   [Sample 4/5] Joshua Morrow...
#   [Sample 5/5] Joshua Morrow...
#
# Saved d:\Github Repositories\SemanticEnergy\backend\data\checkpoint_100_qwen3-8b_benchmark_nqopen.pkl
#   [Sample 1/5] The New England Patriots won the most games in the 2017 NFL season with a record...
#   [Sample 2/5] The New England Patriots won the most games in the NFL 2017 season with a record...
#   [Sample 3/5] The New England Patriots won the most games in the 2017 NFL season with a record...
#   [Sample 4/5] The New England Patriots won the most games in the NFL 2017 season with a 14-2 r...
#   [Sample 5/5] The New England Patriots won the most games in the 2017 NFL season with a record...
#   [Sample 1/5] 25 years old...
#   [Sample 2/5] 25 years old....
#   [Sample 3/5] 25 years old....
#   [Sample 4/5] 25 years old....
#   [Sample 5/5] 25 years old....
#   [Sample 1/5] Drew Brees holds the record for the most career passes intercepted in NFL histor...
#   [Sample 2/5] Charlie Hustle, 1,254 catches....
#   [Sample 3/5] Richie Incognito...
#   [Sample 4/5] Curtis Martin has the most catches in NFL history....
#   [Sample 5/5] Richie Incognito holds the record for the most career passes defensed in NFL his...
#   [Sample 1/5] The DLC for Rainbow Six Siege, known as "Operation: Blackout," was released on O...
#   [Sample 2/5] The DLC for Rainbow Six Siege, known as "Operation: Blackout," was released on J...
#   [Sample 3/5] The DLC for Rainbow Six Siege, known as the "Operation: Stranglehold" expansion,...
#   [Sample 4/5] The DLC for Rainbow Six Siege, known as "Operation: Firebreak," was released on ...
#   [Sample 5/5] The DLC for Rainbow Six Siege, known as "Operation: Jackal," was released on Jun...
#   [Sample 1/5] The Great Wall of China was built to defend against invasions from northern noma...
#   [Sample 2/5] The Great Wall of China was built to defend against invasions from northern noma...
#   [Sample 3/5] The Great Wall of China was built to defend against invasions from northern noma...
#   [Sample 4/5] The Great Wall of China was built to defend against invasions from nomadic group...
#   [Sample 5/5] The Great Wall of China was built to defend against invasions from nomadic group...
#   [Sample 1/5] The last name Galvez is of Spanish origin, derived from the word "gallo," meanin...
#   [Sample 2/5] The last name Galvez originates from the Spanish and Portuguese regions, derived...
#   [Sample 3/5] The last name Galvez originates from Spain, specifically from the region of Anda...
#   [Sample 4/5] The last name Galvez is of Spanish origin, derived from the word "gallo," meanin...
#   [Sample 5/5] The last name Galvez originates from the Spanish region of Galicia, meaning "fro...
#   [Sample 1/5] The Church of the Holy Sepulchre was opened by Emperor Constantine the Great in ...
#   [Sample 2/5] The Church of the Holy Sepulchre was opened by Emperor Constantine the Great in ...
#   [Sample 3/5] The Church of the Holy Sepulchre was opened by Emperor Constantine the Great in ...
#   [Sample 4/5] The Church of the Holy Sepulchre was opened by Emperor Constantine the Great in ...
#   [Sample 5/5] The Church of the Holy Sepulchre was opened by Emperor Constantine the Great in ...
#   [Sample 1/5] Season 5 of *The Blacklist* resumed on September 28, 2016....
#   [Sample 2/5] Season 5 of *The Blacklist* resumed airing on September 28, 2016....
#   [Sample 3/5] Season 5 of *The Blacklist* resumed airing on September 28, 2016....
#   [Sample 4/5] Season 5 of *The Blacklist* resumed on September 28, 2016....
#   [Sample 5/5] Season 5 of *The Blacklist* resumed airing on October 11, 2016....
#   [Sample 1/5] The Chinese dragons are protectors of four seas....
#   [Sample 2/5] The Chinese dragons are protectors of four seas....
#   [Sample 3/5] Chinese dragons are protectors of the four seas....
#   [Sample 4/5] Chinese dragons are protectors of the four seas....
#   [Sample 5/5] The Chinese dragons are protectors of the four seas....
#   [Sample 1/5] Approximately $250 million....
#   [Sample 2/5] Approximately $250 million....
#   [Sample 3/5] Approximately $250 million....
#   [Sample 4/5] Approximately $250 million....
#   [Sample 5/5] Approximately $250 million....
#   [Sample 1/5] The Tower of Pisa leans at an angle of approximately 3.9 degrees from the vertic...
#   [Sample 2/5] The Tower of Pisa leans at an angle of approximately 3.9 degrees from the vertic...
#   [Sample 3/5] The Tower of Pisa leans at an angle of approximately 3.9 degrees from the vertic...
#   [Sample 4/5] The Tower of Pisa leans at an angle of approximately 3.9 degrees from the vertic...
#   [Sample 5/5] The Tower of Pisa leans at an angle of approximately 3.9 degrees from the vertic...
#   [Sample 1/5] As of recent data, agriculture contributes approximately 15-18% to India's GDP....
#   [Sample 2/5] As of recent data, agriculture contributes approximately 15-18% to India's GDP....
#   [Sample 3/5] As of recent data, agriculture contributes around 15-18% to India's GDP....
#   [Sample 4/5] The share of agriculture in India's economy has been declining over the years, c...
#   [Sample 5/5] As of recent data, agriculture contributes around 15-18% to India's GDP....
#   [Sample 1/5] Hermia...
#   [Sample 2/5] Hermia...
#   [Sample 3/5] Hermia...
#   [Sample 4/5] Hermia...
#   [Sample 5/5] Hermia...
#   [Sample 1/5] The movie *Varsity Blues* came out on June 13, 1999....
#   [Sample 2/5] The movie *Varsity Blues* came out on September 27, 1999....
#   [Sample 3/5] The movie *Varsity Blues* came out on June 15, 1999....
#   [Sample 4/5] The movie *Varsity Blues* came out on May 16, 1999....
#   [Sample 5/5] The movie *Varsity Blues* came out on June 19, 1999....
#   [Sample 1/5] The UEFA Champions League quarter-finals typically start in late April or early ...
#   [Sample 2/5] The Champions League quarter-finals typically start in early April, with the exa...
#   [Sample 3/5] The UEFA Champions League quarter-finals typically start in late April or early ...
#   [Sample 4/5] The UEFA Champions League quarter-finals typically start in late April, with the...
#   [Sample 5/5] The Champions League quarter-finals typically start in late April or early May, ...
#   [Sample 1/5] Ernest Rutherford...
#   [Sample 2/5] Ernest Rutherford...
#   [Sample 3/5] Ernest Rutherford...
#   [Sample 4/5] Ernest Rutherford...
#   [Sample 5/5] Ernest Rutherford...
#   [Sample 1/5] A cashier's check is obtained from a bank....
#   [Sample 2/5] A cashier's check is obtained from a bank....
#   [Sample 3/5] A cashier's check is obtained from a bank....
#   [Sample 4/5] A cashier's check is obtained from a bank....
#   [Sample 5/5] A cashier's check is obtained from a bank....
#   [Sample 1/5] Damon Salvatore....
#   [Sample 2/5] Stefan Salvatore marries Elena Gilbert....
#   [Sample 3/5] Stefan Salvatore marries Elena Gilbert in *The Vampire Diaries*....
#   [Sample 4/5] Stefan Salvatore marries Caroline Forbes....
#   [Sample 5/5] Stefan Salvatore marries Elena Gilbert in *The Vampire Diaries*....
#   [Sample 1/5] CC stands for "Carbon Copy" and BCC stands for "Blind Carbon Copy." CC sends a c...
#   [Sample 2/5] CC stands for "Carbon Copy" and BCC stands for "Blind Carbon Copy" in email. CC ...
#   [Sample 3/5] CC stands for "Carbon Copy" and BCC stands for "Blind Carbon Copy." CC sends a c...
#   [Sample 4/5] CC stands for "Carbon Copy" and BCC stands for "Blind Carbon Copy" in email. CC ...
#   [Sample 5/5] CC stands for "Carbon Copy" and BCC stands for "Blind Carbon Copy" in email. CC ...
#   [Sample 1/5] There is no character named Hazel's boyfriend in *The Fault in Our Stars*. Hazel...
#   [Sample 2/5] There is no character named Hazel in "The Fault in Our Stars." The main characte...
#   [Sample 3/5] There is no character named Hazel's boyfriend in *The Fault in Our Stars*. Hazel...
#   [Sample 4/5] There is no official character named Hazel's boyfriend in "The Fault in Our Star...
#   [Sample 5/5] There is no character named Hazel's boyfriend in "The Fault in Our Stars." Hazel...
#   [Sample 1/5] The Day of the Dead ends on November 2nd....
#   [Sample 2/5] The Day of the Dead ends on November 2nd....
#   [Sample 3/5] The Day of the Dead ends on November 2nd....
#   [Sample 4/5] The Day of the Dead typically ends on November 2nd....
#   [Sample 5/5] The Day of the Dead ends on November 2nd....
#   [Sample 1/5] People born on February 29 celebrate their birthday on February 28 or March 1 in...
#   [Sample 2/5] People born on February 29 celebrate their birthday on February 28 or March 1 in...
# ...
#   [Sample 1/5] Yuzuru Hanyu of Japan won the men's singles ice skating event at the 2018 Winter...
#   [Sample 2/5] Yuzuru Hanyu of Japan won the men's singles ice skating event at the 2018 Winter...
#   [Sample 3/5] Yuzuru Hanyu of Japan won the men's single ice skating event at the 2018 Winter ...
#   [Sample 4/5] Yuzuru Hanyu of Japan won the men's singles ice skating event at the 2018 Winter...
#   [Sample 5/5] Yuzuru Hanyu of Japan won the men's singles ice skating event at the 2018 Winter...
#   [Sample 1/5] The boy who played Charlie in Willy Wonka is currently living in the UK....
#   [Sample 2/5] The boy who played Charlie in Willy Wonka is now known as Charlie Bucket, and he...
#   [Sample 3/5] The boy who played Charlie in Willy Wonka is currently living in the United Stat...
#   [Sample 4/5] The boy who played Charlie in *Willy Wonka & the Chocolate Factory* is Peter Ost...
#   [Sample 5/5] The boy who played Charlie in Willy Wonka is currently living in the UK....
#   [Sample 1/5] Shillong...
#   [Sample 2/5] Shillong...
#   [Sample 3/5] Shillong...
#   [Sample 4/5] Shillong...
#   [Sample 5/5] Shillong...
#   [Sample 1/5] Alicia Braga played the Ice Queen in *The Chronicles of Narnia: Prince Caspian*....
#   [Sample 2/5] Amanda Seyfried played the Ice Queen in *The Chronicles of Narnia: The Voyage of...
#   [Sample 3/5] Miranda Otto played the Ice Queen in *The Chronicles of Narnia: The Lion, the Wi...
#   [Sample 4/5] Amanda Seyfried played the Ice Queen in *The Chronicles of Narnia: Prince Caspia...
#   [Sample 5/5] Amanda Seyfried played the Ice Queen in *The Chronicles of Narnia: The Lion, the...
#   [Sample 1/5] Season 2 of *Jessica Jones* was released on December 1, 2017....
#   [Sample 2/5] Season 2 of *Jessica Jones* was released on April 13, 2018....
#   [Sample 3/5] Season 2 of *Jessica Jones* was released on December 1, 2017....
#   [Sample 4/5] Season 2 of *Jessica Jones* was released on **September 13, 2018**....
#   [Sample 5/5] Season 2 of Jessica Jones was released on April 13, 2018....
#   [Sample 1/5] The United Nations Convention on the Rights of the Child was created in 1989....
#   [Sample 2/5] The United Nations Convention on the Rights of the Child was created in 1989....
#   [Sample 3/5] The United Nations Convention on the Rights of the Child was created in 1989....
#   [Sample 4/5] The United Nations Convention on the Rights of the Child was created in 1989....
#   [Sample 5/5] The United Nations Convention on the Rights of the Child was created in 1989....
#   [Sample 1/5] Pyotr Ilyich Tchaikovsky....
#   [Sample 2/5] Peter Ilyich Tchaikovsky...
#   [Sample 3/5] Pyotr Ilyich Tchaikovsky....
#   [Sample 4/5] Pyotr Ilyich Tchaikovsky...
#   [Sample 5/5] Pyotr Ilyich Tchaikovsky...
#   [Sample 1/5] Library literature and information science is a type of academic and research da...
#   [Sample 2/5] Library literature and information science is a type of academic and research da...
#   [Sample 3/5] Library literature and information science is a type of academic and research da...
#   [Sample 4/5] Library literature and information science is a type of academic and research da...
#   [Sample 5/5] Library literature and information science is a type of academic and research da...
#   [Sample 1/5] The United States began using the death penalty as early as 1608, with the first...
#   [Sample 2/5] The United States began using the death penalty as early as 1608, with the first...
#   [Sample 3/5] The United States began using the death penalty in 1608....
#   [Sample 4/5] The United States began using the death penalty as early as 1608, with the first...
#   [Sample 5/5] The United States began using the death penalty in 1608, when the British colony...
#   [Sample 1/5] Coffee was first made into a drink around the 9th century in the Arabian Peninsu...
#   [Sample 2/5] Coffee was first made into a drink around the 9th century in the Arabian Peninsu...
#   [Sample 3/5] Coffee was first made into a drink around the 9th century in the Arabian Peninsu...
#   [Sample 4/5] Coffee was first made into a drink around the 9th century in the Arabian Peninsu...
#   [Sample 5/5] Coffee was first made into a drink around the 9th century in the Arabian Peninsu...
#   [Sample 1/5] Jared is a fictional character on the soap opera "The Bold and the Beautiful," k...
#   [Sample 2/5] Jared is a fictional character on the soap opera "The Bold and the Beautiful," p...
#   [Sample 3/5] Jared is a fictional character on the soap opera "The Bold and the Beautiful," p...
#   [Sample 4/5] Jared is a character on the soap opera "The Bold and the Beautiful" who is the s...
#   [Sample 5/5] Jared is a fictional character on the soap opera "The Bold and the Beautiful," p...
#   [Sample 1/5] "Knock Knock Knocking on Heaven's Door" was written by Bob Dylan....
#   [Sample 2/5] "Knock Knock Knocking on Heaven's Door" was written by Bob Dylan....
#   [Sample 3/5] "Knock Knock Knocking on Heaven's Door" was written by Bob Dylan....
#   [Sample 4/5] The song "Knock Knock Knocking on Heaven's Door" was written by Bob Dylan....
#   [Sample 5/5] "Knock Knock Knocking on Heaven's Door" was written by Bob Dylan....
#   [Sample 1/5] The movie *Napoleon Dynamite* came out on July 29, 2004....
#   [Sample 2/5] The movie *Napoleon Dynamite* came out on November 17, 2004....
#   [Sample 3/5] The movie *Napoleon Dynamite* came out on July 14, 2004....
#   [Sample 4/5] The movie *Napoleon Dynamite* came out on July 29, 2004....
#   [Sample 5/5] The movie *Napoleon Dynamite* was released on July 29, 2004....
#   [Sample 1/5] Richard Gere and Debra Winger starred in *An Officer and a Gentleman*....
#   [Sample 2/5] Richard Gere and Melanie Griffith starred in *An Officer and a Gentleman*....
#   [Sample 3/5] Richard Gere and Debra Winger starred in *An Officer and a Gentleman*....
#   [Sample 4/5] Richard Gere and Miami Dolphins quarterback Dan Marino starred in "An Officer an...
#   [Sample 5/5] Richard Gere and Miami Vice star James Woods....
#   [Sample 1/5] Julie Walters...
#   [Sample 2/5] Julia刚在《Call the Midwife》中饰演了Chummy的妈妈。...
#   [Sample 3/5] Julie Walters...
#   [Sample 4/5] Julie Walters...
#   [Sample 5/5] Imelda Staunton...
#   [Sample 1/5] Keratin and collagen....
#   [Sample 2/5] Keratin and collagen....
#   [Sample 3/5] Keratin and collagen....
#   [Sample 4/5] Keratin and collagen....
#   [Sample 5/5] Keratin and collagen....
#   [Sample 1/5] The New England Patriots have played in 9 Super Bowl games....
#   [Sample 2/5] The New England Patriots have played in 10 Super Bowl games....
#   [Sample 3/5] The New England Patriots have played in 9 Super Bowl games....
#   [Sample 4/5] The New England Patriots have played in 9 Super Bowl games....
#   [Sample 5/5] The New England Patriots have played in 9 Super Bowl games....
#   [Sample 1/5] In "The Vampire Diaries" universe, vampires are placed in a tomb, specifically t...
#   [Sample 2/5] In "The Vampire Chronicles" by Anne Rice, vampires are burned in a special tomb ...
#   [Sample 3/5] In "The Vampire Diaries" series, vampires are placed in the Founder's Day bonfir...
#   [Sample 4/5] In "The Vampire Diaries" universe, vampires are placed in a tomb, typically the ...
#   [Sample 5/5] In "The Vampire Diaries," vampires are burned in the Founder's Day bonfire, whic...
#   [Sample 1/5] As of 2023, the King of the Netherlands is King Willem-Alexander, and the Queen ...
#   [Sample 2/5] As of 2023, the King of the Netherlands is King Willem-Alexander, and the Queen ...
#   [Sample 3/5] As of 2023, the King of the Netherlands is King Willem-Alexander, and the Queen ...
#   [Sample 4/5] As of 2023, the King of the Netherlands is King Willem-Alexander, and the Queen ...
#   [Sample 5/5] As of 2023, the King of the Netherlands is King Willem-Alexander, and the Queen ...
#   [Sample 1/5] The gall bladder is situated in the upper right part of the abdomen, beneath the...
#   [Sample 2/5] The gall bladder is situated in the upper right part of the abdomen, beneath the...
#   [Sample 3/5] The gall bladder is situated in the upper right quadrant of the abdomen, beneath...
#   [Sample 4/5] The gall bladder is situated in the upper right quadrant of the abdomen, just be...
#   [Sample 5/5] The gall bladder is situated in the upper right part of the abdomen, beneath the...
#   [Sample 1/5] As of 2023, the population of Bora Bora is approximately 10,000....
#   [Sample 2/5] As of 2023, the population of Bora Bora is approximately 11,000....
#   [Sample 3/5] As of 2023, the population of Bora Bora is approximately 12,000....
#   [Sample 4/5] As of 2023, the population of Bora Bora is approximately 11,000....
#   [Sample 5/5] As of 2023, the population of Bora Bora is approximately 12,000....
#   [Sample 1/5] The Tropic of Cancer passes through the state of Gujarat in India....
#   [Sample 2/5] The Tropic of Cancer passes through the state of Gujarat in India....
#   [Sample 3/5] The Tropic of Cancer passes through the state of Gujarat in India....
#   [Sample 4/5] The Tropic of Cancer passes through the state of Gujarat in India....
#   [Sample 5/5] The Tropic of Cancer passes through the state of Gujarat in India....
#   [Sample 1/5] The song "Falling in Love with You" was made by Tony Rich....
#   [Sample 2/5] The song "Falling in Love with You" was made by Carole King and Toni Stern....
#   [Sample 3/5] The song "Falling in Love with You" was made by Jimmy Kennedy and George David W...
#   [Sample 4/5] The song "Falling in Love with You" was made by Paul Anka....
#   [Sample 5/5] The song "Falling in Love with You" was made by Paul Anka....
#   [Sample 1/5] Electricity...
#   [Sample 2/5] Electricity...
#   [Sample 3/5] Electricity...
#   [Sample 4/5] Electricity...
#   [Sample 5/5] Electricity...
#   [Sample 1/5] The first book of Percy Jackson is *The Lightning Thief*....
#   [Sample 2/5] The first book of Percy Jackson is **"Percy Jackson & the Olympians: The Lightni...
#   [Sample 3/5] The first book of Percy Jackson is *The Lightning Thief*....
#   [Sample 4/5] The first book of Percy Jackson is *Percy Jackson & the Olympians: The Lightning...
#   [Sample 5/5] The first book of Percy Jackson is *Percy Jackson & the Olympians: The Lightning...
#   [Sample 1/5] The role of Indiana Jones was originally intended for Frank Langella, but he dec...
#   [Sample 2/5] Actor Harrison Ford was originally cast to play Indiana Jones....
#   [Sample 3/5] The original cast for Indiana Jones was Harrison Ford....
#   [Sample 4/5] Actor Harrison Ford was originally cast to play Indiana Jones....
#   [Sample 5/5] The role of Indiana Jones was originally intended for George Lucas, but he decli...
#   [Sample 1/5] The proposition that made the insurance commissioner an elected position was Pro...
#   [Sample 2/5] The proposition that made the insurance commissioner an elected position was Pro...
#   [Sample 3/5] The proposition that made the insurance commissioner an elected position was Pro...
#   [Sample 4/5] The proposition that made the insurance commissioner an elected position was Pro...
#   [Sample 5/5] The proposition that made the insurance commissioner an elected position was Pro...
#   [Sample 1/5] Amy Grant performed "I Can Only Imagine" in the 1993 film *I Can Only Imagine*....
#   [Sample 2/5] Amy Grant performed "I Can Only Imagine" in the 1993 film *I Can Only Imagine*....
#   [Sample 3/5] Amy Grant performed "I Can Only Imagine" on the 1995 TV movie *I Can Only Imagin...
#   [Sample 4/5] Amy Grant performed "I Can Only Imagine" in the 1993 film *The Best Man*....
#   [Sample 5/5] Amy Grant performed "I Can Only Imagine" in the 1993 film *I Can Only Imagine*....
#   [Sample 1/5] The song "Only in My Dreams" is performed by The Beatles....
#   [Sample 2/5] The song "Only in My Dreams" is performed by The Beatles....
#   [Sample 3/5] The song "Only in My Dreams" is performed by The Beatles....
#   [Sample 4/5] The song "Only in My Dreams" is performed by The Beatles....
#   [Sample 5/5] The song "Only in My Dreams" is performed by The Beatles....
#   [Sample 1/5] The Chair of the Federal Reserve System is appointed by the President of the Uni...
#   [Sample 2/5] The Chair of the Federal Reserve System is appointed by the President of the Uni...
#   [Sample 3/5] The Chair of the Federal Reserve System is appointed by the President of the Uni...
#   [Sample 4/5] The chair of the Federal Reserve System is appointed by the President of the Uni...
#   [Sample 5/5] The Chair of the Federal Reserve System is appointed by the President of the Uni...
#   [Sample 1/5] The winner of the next *Iron Chef: Super Chefs* has not been officially announce...
#   [Sample 2/5] The winner of the next *Iron Chef: Super Chefs* has not been officially announce...
#   [Sample 3/5] The winner of the next *Iron Chef: Super Chefs* has not been officially announce...
#   [Sample 4/5] The winner of the next *Iron Chef: Super Chefs* has not been announced yet....
#   [Sample 5/5] The winner of the next *Iron Chef: Super Chefs* has not been announced yet....
#   [Sample 1/5] Body temperature tends to be lowest in the early morning, typically between 4 an...
#   [Sample 2/5] Body temperature tends to be lowest in the early morning, typically between 4 an...
#   [Sample 3/5] Body temperature tends to be lowest in the early morning, around 4 to 5 a.m....
#   [Sample 4/5] Body temperature tends to be lowest in the early morning, typically between 4 a....
#   [Sample 5/5] Body temperature tends to be lowest in the early morning, typically between 4 a....
#   [Sample 1/5] The song "Whiskey Ain't Workin' No More" is performed by The Band....
#   [Sample 2/5] The song "Whiskey Ain't Workin' No More" is performed by Shakin' Stevens....
#   [Sample 3/5] The song "Whiskey Ain't Workin' No More" is performed by The Black Keys....
#   [Sample 4/5] The song "Whiskey Ain't Workin' No More" is performed by Shakin' Stevens....
#   [Sample 5/5] The song "Whiskey Ain't Workin' No More" is sung by George Strait....
#   [Sample 1/5] 2023...
#   [Sample 2/5] 2024...
#   [Sample 3/5] 2024...
#   [Sample 4/5] 2023...
#   [Sample 5/5] 2023...
#   [Sample 1/5] The Chief Ministers of Tamil Nadu mentioned on Wikipedia include M. Karunanidhi,...
#   [Sample 2/5] The Chief Ministers of Tamil Nadu mentioned on Wikipedia include: M. Karunanidhi...
#   [Sample 3/5] The Chief Ministers of Tamil Nadu mentioned on Wikipedia include M. Karunanidhi,...
#   [Sample 4/5] The Chief Ministers of Tamil Nadu mentioned on Wikipedia include M. Karunanidhi,...
#   [Sample 5/5] Yes, the Chief Ministers of Tamil Nadu are listed on the Wikipedia page for "Lis...
#   [Sample 1/5] A political action committee (PAC) is a group that raises and spends money to el...
#   [Sample 2/5] A Political Action Committee (PAC) is a group that raises and spends money to el...
#   [Sample 3/5] A Political Action Committee (PAC) is a group that raises and spends money to el...
#   [Sample 4/5] A political action committee (PAC) raises and spends money to elect or defeat ca...
#   [Sample 5/5] A political action committee (PAC) is a group that raises and spends money to el...
#   [Sample 1/5] As of 2023, the user with the most followers on Instagram is Cristiano Ronaldo, ...
#   [Sample 2/5] As of 2023, the user with the most followers on Instagram is Cristiano Ronaldo, ...
#   [Sample 3/5] As of 2023, the user with the most followers on Instagram is Cristiano Ronaldo, ...
#   [Sample 4/5] As of 2023, the user with the most followers on Instagram is Cristiano Ronaldo....
#   [Sample 5/5] As of 2023, the user with the most followers on Instagram is Cristiano Ronaldo, ...
#   [Sample 1/5] El Salvador has a presidential representative democratic republic....
#   [Sample 2/5] El Salvador has a representative democratic republic political system....
#   [Sample 3/5] El Salvador has a presidential representative democratic republic system....
#   [Sample 4/5] El Salvador has a presidential representative democratic republic....
#   [Sample 5/5] El Salvador has a presidential representative democratic republic....
#
# Saved d:\Github Repositories\SemanticEnergy\backend\data\checkpoint_200_qwen3-8b_benchmark_nqopen.pkl
# Done. 200 records, 0 errors

# %%
# ── Dataset summary ──────────────────────────────────────────────────────────
valid_records = [r for r in records if r['emb_tok_before_eos'] is not None
                 and r['emb_last_tok_before_gen'] is not None]
dropped = len(records) - len(valid_records)
if dropped > 0:
    print(f"Dropped {dropped} records with missing hidden states")

cs = np.array([r['correctness'] for r in valid_records])
es = np.array([r['energy_score_raw'] for r in valid_records])
hs = np.array([r['entropy_score_raw'] for r in valid_records])

print(f"\n{'='*60}")
print(f"Benchmark: {MODEL_LABEL} on {EVAL_DATASET}")
print(f"{'='*60}")
print(f"Valid records:    {len(valid_records)}")
print(f"Correctness rate: {cs.mean():.3f} ({cs.sum():.0f}/{len(cs)})")
print(f"Energy:  mean={es.mean():.4f}, std={es.std():.4f}")
print(f"Entropy: mean={hs.mean():.4f}, std={hs.std():.4f}")

if cs.mean() < 0.10 or cs.mean() > 0.95:
    print(f"\n*** WARNING: Extreme correctness rate ({cs.mean():.1%}) — "
          f"metrics may be unreliable with this class imbalance ***")

# Save final benchmark dataset
out_path = os.path.join(DATA_DIR, f'benchmark_{MODEL_SHORT}_{EVAL_SHORT}.pkl')
with open(out_path, 'wb') as f: pickle.dump(valid_records, f)
print(f"\nSaved: {out_path} ({os.path.getsize(out_path) / 1024**2:.1f} MB)")
# Out:
# ============================================================
# Benchmark: Qwen3-8B on nq_open
# ============================================================
# Valid records:    200
# Correctness rate: 0.320 (64/200)
# Energy:  mean=0.6991, std=0.3312
# Entropy: mean=0.5079, std=0.5524
#
# Saved: d:\Github Repositories\SemanticEnergy\backend\data\benchmark_qwen3-8b_nqopen.pkl (231.3 MB)

# %% [markdown]
# ## 2 — Evaluation with Pre-trained Probes

# %%
# ── Build ProbeDataset (no train/val/test split — all data is eval) ──────────

class ProbeDataset:
    def __init__(self, records, name='eval'):
        self.name, self.N = name, len(records)
        self.energy_score_raw  = np.array([r['energy_score_raw']  for r in records])
        self.entropy_score_raw = np.array([r['entropy_score_raw'] for r in records])
        self.correctness = np.array([r['correctness'] for r in records])
        self.tbg_states = np.stack([r['emb_last_tok_before_gen'] for r in records])
        self.slt_states = np.stack([r['emb_tok_before_eos']      for r in records])
        self.num_layers = self.tbg_states.shape[1]
        self.hidden_dim = self.tbg_states.shape[2]
        self.logit_feats = np.nan_to_num(np.array([
            [r['logit_feats']['mean_chosen_logit'], r['logit_feats']['min_chosen_logit'],
             r['logit_feats']['std_chosen_logit'], float(r['logit_feats']['answer_len'])]
            for r in records], dtype=np.float64), nan=0., posinf=0., neginf=0.)
        self.energy_label = None
        self.entropy_label = None
        print(f"ProbeDataset '{name}': N={self.N}, layers={self.num_layers}, hidden={self.hidden_dim}")

D_eval = ProbeDataset(valid_records, name=f'eval_{EVAL_SHORT}')

# Apply TriviaQA thresholds for binarization (zero-shot transfer)
D_eval.energy_label  = (D_eval.energy_score_raw  >= T_energy).astype(int)
D_eval.entropy_label = (D_eval.entropy_score_raw >= T_entropy).astype(int)

print(f"\nBinarization (TriviaQA thresholds — T_energy={T_energy:.4f}, T_entropy={T_entropy:.4f}):")
print(f"  Energy label balance:  {D_eval.energy_label.mean():.3f} positive")
print(f"  Entropy label balance: {D_eval.entropy_label.mean():.3f} positive")
# Out:
# ProbeDataset 'eval_nqopen': N=200, layers=37, hidden=4096
#
# Binarization (TriviaQA thresholds — T_energy=0.6682, T_entropy=0.5556):
#   Energy label balance:  0.575 positive
#   Entropy label balance: 0.395 positive

# %%
# ── Evaluation functions ─────────────────────────────────────────────────────

def fpr_at_tpr(y_true, y_score, target_tpr=0.95):
    fpr, tpr, _ = roc_curve(y_true, y_score)
    idx = np.where(tpr >= target_tpr)[0]
    if len(idx) == 0:
        return 1.0
    return float(fpr[idx[0]])

def full_eval(y_true, y_score):
    auroc = roc_auc_score(y_true, y_score)
    aupr  = average_precision_score(y_true, y_score)
    fpr95 = fpr_at_tpr(y_true, y_score, 0.95)
    return {'auroc': auroc, 'aupr': aupr, 'fpr95': fpr95}

def bootstrap_full_eval(y_true, y_score, n_boot=1000, ci=0.95):
    base = full_eval(y_true, y_score)
    boot = {'auroc': [], 'aupr': [], 'fpr95': []}
    rng = np.random.default_rng(0)
    for _ in range(n_boot):
        idx = rng.integers(0, len(y_true), len(y_true))
        if len(np.unique(y_true[idx])) < 2: continue
        b = full_eval(y_true[idx], y_score[idx])
        for k in boot: boot[k].append(b[k])
    alpha = (1 - ci) / 2
    result = {}
    for k in base:
        result[k] = {
            'mean': base[k],
            'lo': np.percentile(boot[k], alpha * 100),
            'hi': np.percentile(boot[k], (1 - alpha) * 100),
        }
    return result

def get_range_X(D, lr, token='slt'):
    return (D.slt_states if token == 'slt' else D.tbg_states)[:, lr[0]:lr[1], :].reshape(D.N, -1)

def clean_X(X):
    return np.nan_to_num(np.array(X, dtype=np.float64), nan=0., posinf=0., neginf=0.)

def get_hall_score(pname, p_info, D):
    X = get_range_X(D, p_info['layer_range'], p_info['token'])
    s = p_info['probe'].predict_proba(p_info['scaler'].transform(clean_X(X)))[:, 1]
    return 1 - s if 'energy' in pname else s

def optimal_threshold(y_true, y_score):
    fpr, tpr, thresholds = roc_curve(y_true, y_score)
    j = tpr - fpr
    return thresholds[np.argmax(j)]

def save_fig(name):
    p = os.path.join(FIGS_DIR, f'{name}_{MODEL_SHORT}.png')
    plt.savefig(p, dpi=120, bbox_inches='tight')
    print(f"Saved: {p}")

print("Evaluation functions defined.")
# Out:
# Evaluation functions defined.

# %%
# ── All-systems evaluation against ground-truth correctness ──────────────────
y_hall = 1 - D_eval.correctness

systems = [
    ('Energy teacher (UB)',  1 - D_eval.energy_score_raw),
    ('Entropy teacher (UB)', D_eval.entropy_score_raw),
    ('SLT energy probe',     get_hall_score('slt_energy', trained_probes['slt_energy'], D_eval)),
    ('TBG energy probe',     get_hall_score('tbg_energy', trained_probes['tbg_energy'], D_eval)),
    ('SLT entropy probe',    get_hall_score('slt_entropy', trained_probes['slt_entropy'], D_eval)),
    ('TBG entropy probe',    get_hall_score('tbg_entropy', trained_probes['tbg_entropy'], D_eval)),
]

print(f"\nHallucination Detection — {MODEL_LABEL} on {EVAL_DATASET} (n={D_eval.N})")
print(f"Hallucination rate: {y_hall.mean():.1%}\n")
print(f"{'System':<25} {'AUROC':>8} {'95% CI':>16} {'AUPR':>8} {'95% CI':>16} {'FPR@95':>8} {'95% CI':>16}")
print("-" * 100)

sys_results = []
for name, scores in systems:
    r = bootstrap_full_eval(y_hall, scores)
    sys_results.append((name, r))
    print(f"{name:<25} "
          f"{r['auroc']['mean']:>8.4f} [{r['auroc']['lo']:.4f}, {r['auroc']['hi']:.4f}]  "
          f"{r['aupr']['mean']:>8.4f} [{r['aupr']['lo']:.4f}, {r['aupr']['hi']:.4f}]  "
          f"{r['fpr95']['mean']:>8.4f} [{r['fpr95']['lo']:.4f}, {r['fpr95']['hi']:.4f}]")
# Out:
# Hallucination Detection — Qwen3-8B on nq_open (n=200)
# Hallucination rate: 68.0%
#
# System                       AUROC           95% CI     AUPR           95% CI   FPR@95           95% CI
# ----------------------------------------------------------------------------------------------------
# Energy teacher (UB)         0.6949 [0.6251, 0.7636]    0.7997 [0.7187, 0.8666]    1.0000 [1.0000, 1.0000]
# Entropy teacher (UB)        0.7075 [0.6360, 0.7716]    0.8054 [0.7348, 0.8688]    1.0000 [1.0000, 1.0000]
# SLT energy probe            0.6361 [0.5509, 0.7201]    0.7801 [0.6928, 0.8541]    0.8438 [0.7241, 0.9616]
# TBG energy probe            0.5082 [0.4214, 0.5868]    0.6932 [0.6063, 0.7725]    0.9531 [0.8636, 1.0000]
# SLT entropy probe           0.6450 [0.5575, 0.7274]    0.7804 [0.6929, 0.8548]    0.8594 [0.7463, 0.9643]
# TBG entropy probe           0.4970 [0.4779, 0.5192]    0.6786 [0.6033, 0.7475]    0.9844 [0.9492, 1.0000]

# %%
# ── Performance comparison bar chart ─────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
names  = [s[0] for s in sys_results]
colors = ['#2ecc71', '#27ae60', '#3498db', '#2980b9', '#e67e22', '#d35400']

for ax, metric, title in zip(axes, ['auroc', 'aupr', 'fpr95'],
                              ['AUROC (higher=better)', 'AUPR (higher=better)', 'FPR@95 (lower=better)']):
    vals = [s[1][metric]['mean'] for s in sys_results]
    bars = ax.barh(names, vals, color=colors, alpha=0.85, edgecolor='white')
    for bar, val in zip(bars, vals):
        ax.text(val + 0.005, bar.get_y() + bar.get_height()/2, f'{val:.3f}', va='center', fontsize=8)
    if metric == 'fpr95':
        ax.set_xlim(0, 1.1)
    else:
        ax.axvline(0.5, color='black', ls=':', lw=1)
        ax.set_xlim(0.3, 1.05)
    ax.set_title(title)

plt.suptitle(f'Hallucination Detection \u2014 {MODEL_LABEL} on {EVAL_DATASET} (n={D_eval.N})',
             fontsize=13, fontweight='bold')
plt.tight_layout()
save_fig(f'performance_comparison_benchmark_{EVAL_SHORT}'); plt.show()
# Out:
# Saved: d:\Github Repositories\SemanticEnergy\notebooks\figures\performance_comparison_benchmark_nqopen_qwen3-8b.png

# %%
# ── ROC & Precision-Recall curves ────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# ROC curves
ax = axes[0]
for name, scores in systems[:2]:  # Teachers
    fpr, tpr, _ = roc_curve(y_hall, scores)
    ax.plot(fpr, tpr, ls='--', alpha=0.5, label=name)
for pname in ['slt_energy', 'tbg_energy', 'slt_entropy', 'tbg_entropy']:
    scores = get_hall_score(pname, trained_probes[pname], D_eval)
    fpr_vals, tpr_vals, _ = roc_curve(y_hall, scores)
    label = pname.replace('_', ' ').upper()
    ax.plot(fpr_vals, tpr_vals, label=label)
ax.plot([0,1], [0,1], 'k:', lw=1)
ax.set_xlabel('FPR'); ax.set_ylabel('TPR')
ax.set_title(f'ROC Curves ({MODEL_LABEL} on {EVAL_DATASET})'); ax.legend(fontsize=8)

# PR curves
ax = axes[1]
for name, scores in systems[:2]:
    prec, rec, _ = precision_recall_curve(y_hall, scores)
    ax.plot(rec, prec, ls='--', alpha=0.5, label=name)
for pname in ['slt_energy', 'tbg_energy', 'slt_entropy', 'tbg_entropy']:
    scores = get_hall_score(pname, trained_probes[pname], D_eval)
    prec, rec, _ = precision_recall_curve(y_hall, scores)
    ax.plot(rec, prec, label=pname.replace('_', ' ').upper())
ax.set_xlabel('Recall'); ax.set_ylabel('Precision')
ax.set_title(f'Precision-Recall Curves ({MODEL_LABEL} on {EVAL_DATASET})'); ax.legend(fontsize=8)

plt.tight_layout()
save_fig(f'roc_pr_curves_benchmark_{EVAL_SHORT}'); plt.show()
# Out:
# Saved: d:\Github Repositories\SemanticEnergy\notebooks\figures\roc_pr_curves_benchmark_nqopen_qwen3-8b.png

# %%
# ── Confusion matrices at optimal (Youden's J) threshold ─────────────────────
cm_systems = [
    ('SLT Energy Probe',  get_hall_score('slt_energy', trained_probes['slt_energy'], D_eval)),
    ('TBG Energy Probe',  get_hall_score('tbg_energy', trained_probes['tbg_energy'], D_eval)),
    ('SLT Entropy Probe', get_hall_score('slt_entropy', trained_probes['slt_entropy'], D_eval)),
    ('TBG Entropy Probe', get_hall_score('tbg_entropy', trained_probes['tbg_entropy'], D_eval)),
    ('Energy Teacher',    1 - D_eval.energy_score_raw),
    ('Entropy Teacher',   D_eval.entropy_score_raw),
]

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

cm_summary = []
for ax, (name, scores) in zip(axes, cm_systems):
    thresh = optimal_threshold(y_hall.astype(int), scores)
    y_pred = (scores >= thresh).astype(int)
    cm = confusion_matrix(y_hall.astype(int), y_pred, labels=[0, 1])
    disp = ConfusionMatrixDisplay(cm, display_labels=['Correct', 'Hallucinated'])
    disp.plot(ax=ax, cmap='Blues', colorbar=False, values_format='d')
    tn, fp, fn, tp = cm.ravel()
    accuracy  = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall    = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    ax.set_title(f'{name}\nAcc={accuracy:.2f}  F1={f1:.2f}  (thresh={thresh:.3f})', fontsize=10)
    cm_summary.append({'System': name, 'TP': tp, 'FP': fp, 'TN': tn, 'FN': fn,
                       'Accuracy': accuracy, 'Precision': precision, 'Recall': recall, 'F1': f1})

plt.suptitle(f'Confusion Matrices \u2014 {MODEL_LABEL} on {EVAL_DATASET} (n={len(y_hall)})',
             fontsize=13, fontweight='bold')
plt.tight_layout()
save_fig(f'confusion_matrices_benchmark_{EVAL_SHORT}'); plt.show()

print(f"\n{'System':<22} {'TP':>4} {'FP':>4} {'TN':>4} {'FN':>4} {'Acc':>6} {'Prec':>6} {'Rec':>6} {'F1':>6}")
print('-' * 72)
for r in cm_summary:
    print(f"{r['System']:<22} {r['TP']:>4} {r['FP']:>4} {r['TN']:>4} {r['FN']:>4} "
          f"{r['Accuracy']:>6.3f} {r['Precision']:>6.3f} {r['Recall']:>6.3f} {r['F1']:>6.3f}")
# Out:
# Saved: d:\Github Repositories\SemanticEnergy\notebooks\figures\confusion_matrices_benchmark_nqopen_qwen3-8b.png
# System                   TP   FP   TN   FN    Acc   Prec    Rec     F1
# ------------------------------------------------------------------------
# SLT Energy Probe         89   28   36   47  0.625  0.761  0.654  0.704
# TBG Energy Probe        100   43   21   36  0.605  0.699  0.735  0.717
# SLT Entropy Probe       103   31   33   33  0.680  0.769  0.757  0.763
# TBG Entropy Probe       136   63    1    0  0.685  0.683  1.000  0.812
# Energy Teacher           89   17   47   47  0.680  0.840  0.654  0.736
# Entropy Teacher          89   17   47   47  0.680  0.840  0.654  0.736

# %%
# ── Teacher fidelity (diagnostic only — not a performance metric) ────────────
configs = [
    ('slt_energy',  'energy', 'slt', probe_bundle['best_energy_slt_range']),
    ('tbg_energy',  'energy', 'tbg', probe_bundle['best_energy_tbg_range']),
    ('slt_entropy', 'entropy', 'slt', probe_bundle['best_entropy_slt_range']),
    ('tbg_entropy', 'entropy', 'tbg', probe_bundle['best_entropy_tbg_range']),
]

print(f"Teacher fidelity on {EVAL_DATASET} (Spearman rho — diagnostic only):")
print(f"{'Probe':<15} {'Teacher':<20} {'Spearman rho':>12} {'p-value':>12}")
print("-" * 62)
for pname, teacher, tok, lr in configs:
    teacher_key = f'{teacher}_score_raw'
    raw_teacher = getattr(D_eval, teacher_key)
    X = get_range_X(D_eval, lr, tok)
    p_info = trained_probes[pname]
    probe_score = p_info['probe'].predict_proba(p_info['scaler'].transform(clean_X(X)))[:, 1]
    rho, p = spearmanr(probe_score, raw_teacher)
    print(f"{pname:<15} {teacher_key:<20} {rho:>12.4f} {p:>12.2e}")
# Out:
# Teacher fidelity on nq_open (Spearman rho — diagnostic only):
# Probe           Teacher              Spearman rho      p-value
# --------------------------------------------------------------
# slt_energy      energy_score_raw           0.4272     2.81e-10
# tbg_energy      energy_score_raw           0.1984     4.87e-03
# slt_entropy     entropy_score_raw          0.4413     6.11e-11
# tbg_entropy     entropy_score_raw          0.1390     4.97e-02

# %% [markdown]
# ## 3 — Cross-Dataset Comparison
#
# Run this section **after** running the notebook for all 3 datasets.
# It loads saved benchmark results and builds a comparison table.

# %%
# ── Load all available benchmark results ─────────────────────────────────────
import pandas as pd

benchmark_datasets = {
    'triviaqa': 'TriviaQA (held-out)',
    'nqopen':   'NQ-Open',
    'squad':    'SQuAD',
}

all_results = {}
for ds_short, ds_label in benchmark_datasets.items():
    path = os.path.join(DATA_DIR, f'benchmark_{MODEL_SHORT}_{ds_short}.pkl')
    if not os.path.exists(path):
        print(f"  [{ds_label}] Not found: {path}")
        continue
    with open(path, 'rb') as f:
        recs = pickle.load(f)
    # Filter valid
    recs = [r for r in recs if r['emb_tok_before_eos'] is not None
            and r['emb_last_tok_before_gen'] is not None]
    D = ProbeDataset(recs, name=ds_short)
    y = 1 - D.correctness
    ds_systems = [
        ('Energy teacher (UB)',  1 - D.energy_score_raw),
        ('Entropy teacher (UB)', D.entropy_score_raw),
        ('SLT energy probe',     get_hall_score('slt_energy', trained_probes['slt_energy'], D)),
        ('TBG energy probe',     get_hall_score('tbg_energy', trained_probes['tbg_energy'], D)),
        ('SLT entropy probe',    get_hall_score('slt_entropy', trained_probes['slt_entropy'], D)),
        ('TBG entropy probe',    get_hall_score('tbg_entropy', trained_probes['tbg_entropy'], D)),
    ]
    results = {}
    for name, scores in ds_systems:
        results[name] = full_eval(y, scores)
    results['_correctness_rate'] = float(D.correctness.mean())
    results['_n'] = D.N
    all_results[ds_label] = results
    print(f"  [{ds_label}] Loaded {D.N} records (correctness={D.correctness.mean():.1%})")

print(f"\nLoaded {len(all_results)} benchmark datasets.")
# Out:
#   [TriviaQA (held-out)] Not found: d:\Github Repositories\SemanticEnergy\backend\data\benchmark_qwen3-8b_triviaqa.pkl
# ProbeDataset 'nqopen': N=200, layers=37, hidden=4096
#   [NQ-Open] Loaded 200 records (correctness=32.0%)
#   [SQuAD] Not found: d:\Github Repositories\SemanticEnergy\backend\data\benchmark_qwen3-8b_squad.pkl
#
# Loaded 1 benchmark datasets.

# %%
# ── Cross-dataset summary table ──────────────────────────────────────────────
if len(all_results) == 0:
    print("No benchmark results found. Run the notebook for at least one dataset first.")
else:
    system_names = ['Energy teacher (UB)', 'Entropy teacher (UB)',
                    'SLT energy probe', 'TBG energy probe',
                    'SLT entropy probe', 'TBG entropy probe']

    for metric, metric_label in [('auroc', 'AUROC'), ('aupr', 'AUPR'), ('fpr95', 'FPR@95')]:
        rows = []
        for sname in system_names:
            row = {'System': sname}
            for ds_label, results in all_results.items():
                if sname in results:
                    row[ds_label] = f"{results[sname][metric]:.4f}"
                else:
                    row[ds_label] = '—'
            rows.append(row)
        # Add correctness rate row
        cr_row = {'System': 'Correctness rate'}
        for ds_label, results in all_results.items():
            cr_row[ds_label] = f"{results['_correctness_rate']:.1%}"
        rows.append(cr_row)
        n_row = {'System': 'N'}
        for ds_label, results in all_results.items():
            n_row[ds_label] = str(results['_n'])
        rows.append(n_row)

        df = pd.DataFrame(rows).set_index('System')
        print(f"\n{'='*60}")
        print(f"  {metric_label} — {MODEL_LABEL}")
        print(f"{'='*60}")
        print(df.to_string())
        print()
# Out:
# ============================================================
#   AUROC — Qwen3-8B
# ============================================================
#                      NQ-Open
# System
# Energy teacher (UB)   0.6949
# Entropy teacher (UB)  0.7075
# SLT energy probe      0.6361
# TBG energy probe      0.5082
# SLT entropy probe     0.6450
# TBG entropy probe     0.4970
# Correctness rate       32.0%
# N                        200
#
#
# ============================================================
#   AUPR — Qwen3-8B
# ============================================================
#                      NQ-Open
# System
# Energy teacher (UB)   0.7997
# Entropy teacher (UB)  0.8054
# SLT energy probe      0.7801
# TBG energy probe      0.6932
# SLT entropy probe     0.7804
# TBG entropy probe     0.6786
# Correctness rate       32.0%
# N                        200
#
#
# ============================================================
#   FPR@95 — Qwen3-8B
# ============================================================
#                      NQ-Open
# System
# Energy teacher (UB)   1.0000
# Entropy teacher (UB)  1.0000
# SLT energy probe      0.8438
# TBG energy probe      0.9531
# SLT entropy probe     0.8594
# TBG entropy probe     0.9844
# Correctness rate       32.0%
# N                        200

# %%
# ── Generalization comparison plot ────────────────────────────────────────────
if len(all_results) >= 2:
    system_names = ['Energy teacher (UB)', 'Entropy teacher (UB)',
                    'SLT energy probe', 'SLT entropy probe',
                    'TBG energy probe', 'TBG entropy probe']
    ds_labels = list(all_results.keys())
    ds_colors = ['#3498db', '#e67e22', '#2ecc71', '#e74c3c'][:len(ds_labels)]

    fig, axes = plt.subplots(1, 3, figsize=(20, 7))
    x = np.arange(len(system_names))
    width = 0.8 / len(ds_labels)

    for ax, metric, title in zip(axes, ['auroc', 'aupr', 'fpr95'],
                                  ['AUROC', 'AUPR', 'FPR@95']):
        for j, (ds_label, color) in enumerate(zip(ds_labels, ds_colors)):
            vals = [all_results[ds_label].get(sname, {}).get(metric, 0) for sname in system_names]
            offset = (j - len(ds_labels)/2 + 0.5) * width
            bars = ax.bar(x + offset, vals, width, label=ds_label, color=color, alpha=0.85)
            for bar, val in zip(bars, vals):
                ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.005,
                        f'{val:.2f}', ha='center', va='bottom', fontsize=6, rotation=45)
        ax.set_xticks(x)
        ax.set_xticklabels([s.replace(' (UB)', '\n(UB)').replace(' probe', '\nprobe')
                            for s in system_names], fontsize=7, rotation=0)
        ax.set_title(title)
        ax.legend(fontsize=8)
        if metric != 'fpr95':
            ax.axhline(0.5, color='black', ls=':', lw=1)
            ax.set_ylim(0.3, 1.05)
        else:
            ax.set_ylim(0, 1.1)

    plt.suptitle(f'Cross-Dataset Generalization \u2014 {MODEL_LABEL}\n(Probes trained on TriviaQA)',
                 fontsize=13, fontweight='bold')
    plt.tight_layout()
    save_fig(f'generalization_comparison_{MODEL_SHORT}')
    plt.show()
else:
    print("Need at least 2 benchmark datasets for comparison plot. Run the notebook for more datasets.")
# Out:
# Need at least 2 benchmark datasets for comparison plot. Run the notebook for more datasets.

# %%
# ── Save benchmark results for this run ──────────────────────────────────────
benchmark_result = {
    'model_id': MODEL_ID,
    'train_dataset': TRAIN_DATASET,
    'eval_dataset': EVAL_DATASET,
    'num_questions': D_eval.N,
    'correctness_rate': float(D_eval.correctness.mean()),
    'hallucination_rate': float(y_hall.mean()),
    'systems': {name: {'auroc': r['auroc']['mean'], 'aupr': r['aupr']['mean'],
                       'fpr95': r['fpr95']['mean'],
                       'auroc_ci': [r['auroc']['lo'], r['auroc']['hi']],
                       'aupr_ci': [r['aupr']['lo'], r['aupr']['hi']],
                       'fpr95_ci': [r['fpr95']['lo'], r['fpr95']['hi']]}
               for name, r in sys_results},
    'confusion_matrices': cm_summary,
}

out = os.path.join(DATA_DIR, f'benchmark_results_{MODEL_SHORT}_{EVAL_SHORT}.pkl')
with open(out, 'wb') as f: pickle.dump(benchmark_result, f)
print(f"Benchmark results saved: {out}")
print(f"\nDone! Run this notebook with the next EVAL_DATASET to build the cross-dataset comparison.")
# Out:
# Benchmark results saved: d:\Github Repositories\SemanticEnergy\backend\data\benchmark_results_qwen3-8b_nqopen.pkl
#
# Done! Run this notebook with the next EVAL_DATASET to build the cross-dataset comparison.
